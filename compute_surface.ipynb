# %%
from PIL import Image
from pdf2image import convert_from_path, convert_from_bytes
import fitz
import pandas as pd
import easyocr
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from io import BytesIO
from shapely.plotting import plot_polygon
from collections import defaultdict
import sys
sys.path.insert(1, 'src')
from text_coverage import compute_area, compute_area_ocr, compute_area_pdf_fonts, easy_ocr, preprocess_text, findwords, decontracted, preprocessed_word, find_ner
from nltk.corpus import words
from spellchecker import SpellChecker
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4') 
import math
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/charlottepanuskova/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/charlottepanuskova/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Bold: 'On the Farm (Read and Learn)', 'A Big Book of the Dark'
# Italics: 'Colour in Nature'

# %% [markdown]
# #### PDF method
#
# The method extracts text from PDF pages and identifies the boxes in which the text was typed.
# Boxes with the same font are then merged, and the text is unified.
# It also computes the percentage of text on the page.

# %%
book =  'How Animals Sleep' #'How Flamingo Lost His Colour'#'I Am in Love With My Bicycle' #'How Animals Sleep'#'Our Tom\'s Day'#'Atlas of Cats' #'Shapes and Patterns in Nature'#
pdf_file = f'PDFs/{book}.pdf'
doc = fitz.open(pdf_file)
text_page = {'Book Name': [], 'page': [], 'text':[]}

for i in range(doc.page_count): 
    number_of_boxes = 0
    page = doc[i] 

    # Get text blocks
    text_instances = page.get_text("dict")["blocks"]
    text_area = 0

    # Get the PDF page dimensions
    page_rect = page.rect
    page_area = page_rect.width * page_rect.height

    # Render the page to an image
    zoom = 1  # increase resolution (1=72 dpi, 2=144 dpi, etc.)
    mat = fitz.Matrix(zoom, zoom)
    pix = page.get_pixmap(matrix=mat, alpha=False)

    # Convert to an image PIL can display
    img = Image.open(BytesIO(pix.tobytes("png")))

    # Plot the image
    fig, ax = plt.subplots(figsize=(10, 14))
    ax.imshow(img)
    ax.set_xlim(0, page_rect.width )
    ax.set_ylim(0, page_rect.height )
    ax.invert_yaxis()  # PyMuPDF origin is bottom-left

    rectangles = []
    font_rectangles = defaultdict(list)
    # Draw rectangles for text spans
    text_previous = ''
    for block in text_instances:
        
        if "lines" in block:    
            for line in block["lines"]:
                for span in line["spans"]:
                    text = span["text"]
                    if text_previous == text:
                        continue
                
                    text_previous = text
                    rect = fitz.Rect(span["bbox"])  
                    rectangles.append(rect)
                    number_of_boxes += 1 
                    font,_,_ = (span["font"]).partition('-') # Get the font name before the hyphen
                    font_rectangles[font].append(span) #, span["size"]
                    r = patches.Rectangle(
                        (rect.x0, rect.y0),
                        rect.width,
                        rect.height,
                        linewidth=1,
                        edgecolor='red',
                        facecolor='none'
                    )
                    ax.add_patch(r)
    
    merged, text_area, geoms, geoms_area = compute_area(rectangles)
    
    # Text coverage
    coverage = (text_area / page_area) * 100
    plt.title(f"Page {i} — Coverage: {coverage:.2f}%, Boxes: {number_of_boxes}, Geoms: {geoms}")
    plt.axis('off')
    plt.show()

    merged_all, text_area, geoms, geoms_area, geometries_texts = compute_area_pdf_fonts(font_rectangles)
    coverage = (text_area / page_area ) * 100
    if geoms > 0:
     # Convert to an image PIL can display
        img = Image.open(BytesIO(pix.tobytes("png")))

        # Plot the image
        fig, ax = plt.subplots(figsize=(10, 14))
        ax.imshow(img)
        ax.set_xlim(0, page_rect.width )
        ax.set_ylim(0, page_rect.height )
        ax.invert_yaxis()  # PyMuPDF origin is bottom-left
        for m in merged_all:
            plot_polygon(polygon=m, ax=ax, add_points=False, color="green")
        plt.title(f"Page {i} — Coverage: {coverage:.2f}%, Boxes: {geoms}")
        plt.axis('off')
        plt.show()
        for font, spans in geometries_texts.items():
            print(f"Font: {font}")
            text = preprocess_text(' '.join([span['text'] for span in spans]))
            text = text.strip()
            middle = int(math.floor(len(text)/2))
            if text[0:middle] == text[middle:]:text = text[0:middle]
            print(text)
            text_page['Book Name'].append(book)
            text_page['page'].append(i)
            text_page['text'].append(text)

# %% [markdown]
# #### Find whether words are english or names (mostly Czech)

# %%
import requests
import time

time_sleep = 0.3  # seconds

params = {'data' : 'data',
        'model': 'nametag3-czech-cnec2.0-240830',  
        'input': 'vertical',
        'output': 'vertical'} 
def find_ner(text):
    global params
    try:
        text = ' '.join([word.capitalize() for word in text.split()])
        params['data'] = text
        response = requests.get(url="http://lindat.mff.cuni.cz/services/nametag/api/recognize", params=params)
        response.raise_for_status()  # raises exception when not a 2xx response
        if response.status_code != 204:
            result = response.json()['result']
            result = result.replace("\n", "\t")
            s = result.split('\t')
            s = s[0:-1]
            if len(s) > 1:
                for i in range(0, len(s), 3):
                    print(f'name: {s[i + 2]}, type: {s[i + 1]}')
                    return s[i + 2].lower()
        time.sleep(time_sleep)            
    except Exception as e:
        print("Error:", e)

    return  None

glued_words = []
spell = SpellChecker(language='en')
lemmatizer = nltk.stem.WordNetLemmatizer()
for word_list in text_page['text']:
    word_list = decontracted(word_list.replace('’', "'"))  # Expand contractions
    misspelled = spell.unknown([preprocessed_word(lemmatizer, word) for word in word_list.split() if word.isalpha() and len(word) > 1])
    if len(misspelled) > 0: 
        print(f"Misspelled words: {misspelled}")
        names = []
        for word in misspelled:
            name = find_ner(word)
            if name is not None:
                names.append(name)
        for name in names: 
            misspelled.discard(name)
        #names = find_ner(' '.join(list(misspelled)))
        glued_words.extend(list(misspelled))
# Out:
# Misspelled words: {'katarína', 'bartíková', 'petra', 'macurová'}
# name: Katarína, type: gu
# name: Bartíková, type: ps
# name: Petra, type: pf
# name: Macurová, type: ps
# Misspelled words: {'katarína', 'bartíková', 'petra', 'macurová'}
# name: Katarína, type: gu
# name: Bartíková, type: ps
# name: Petra, type: pf
# name: Macurová, type: ps
# Misspelled words: {'te'}
# Misspelled words: {'th', 'falle', 'tr'}
# Misspelled words: {'ofs'}
# Misspelled words: {'pil', 'ows'}
# Misspelled words: {'sc', 'ina', 'ng'}
# Misspelled words: {'placessomething'}
# Misspelled words: {'smal', 'mamals'}
# Misspelled words: {'el'}
# Misspelled words: {'asian'}
# name: Asian, type: pc
# Misspelled words: {'te', 'ag'}
# Misspelled words: {'gerbi'}
# Misspelled words: {'slele'}
# Misspelled words: {'erbil'}
# name: Erbil, type: pf
# Misspelled words: {'nothin', 'havin', 'ood'}
# name: Havin, type: ps
# Misspelled words: {'ng'}
# Misspelled words: {'iraffe'}
# name: Iraffe, type: p_
# Misspelled words: {'lon'}
# name: Lon, type: pf
# Misspelled words: {'che'}
# Misspelled words: {'doesn'}
# Misspelled words: {'hasthecame'}
# Misspelled words: {'girafgiraf'}
# name: Girafgiraf, type: p_
# Misspelled words: {'slele'}
# Misspelled words: {'fal'}
# Misspelled words: {'tre'}
# Misspelled words: {'itstime'}
# Misspelled words: {'looong'}
# Misspelled words: {'ned'}
# Misspelled words: {'hipos', 'minutesin', 'livingstay'}
# name: Hipos, type: p_
# Misspelled words: {'isa'}
# name: Isa, type: pf
# Misspelled words: {'thehippo', 'itswhole', 'jawwith', 'yawnsyou', 'cansee'}
# name: Yawnsyou, type: ic
# name: Cansee, type: oa
# Misspelled words: {'aroundit', 'smal', 'se'}
# Misspelled words: {'se'}
# Misspelled words: {'sleepin', 'ba'}
# Misspelled words: {'freud'}
# name: Freud, type: ps
# Misspelled words: {'kan', 'aroo'}
# name: Kan, type: gc
# name: Aroo, type: p_
# Misspelled words: {'tres', 'graz', 'gras'}
# name: Graz, type: gu
# Misspelled words: {'ste', 'balanceand'}
# Misspelled words: {'isn'}
# name: Isn, type: or
# Misspelled words: {'kilometre'}
# Misspelled words: {'le', 'ood'}
# Misspelled words: {'le'}
# Misspelled words: {'nde'}
# Misspelled words: {'needn'}
# Misspelled words: {'rol'}
# Misspelled words: {'al', 'shalow'}
# name: Shalow, type: p_
# Misspelled words: {'ful'}
# Misspelled words: {'ng'}
# Misspelled words: {'ng'}
# Misspelled words: {'flamin'}
# Misspelled words: {'walkin', 'swimmin'}
# name: Walkin, type: ps
# name: Swimmin, type: op
# Misspelled words: {'plas'}
# Misspelled words: {'standin', 'le', 'ncredible'}
# Misspelled words: {'milioooooons'}
# Misspelled words: {'eho', 'hed'}
# Misspelled words: {'sharpspines', 'onitsbodythe', 'thousandsof'}
# name: Sharpspines, type: ic
# Misspelled words: {'apetite'}
# Misspelled words: {'bal', 'sleps'}
# Misspelled words: {'wel'}
# name: Wel, type: mn
# Misspelled words: {'fliiiieees'}
# Misspelled words: {'sleps'}
# Misspelled words: {'albatros'}
# name: Albatros, type: C
# Misspelled words: {'tretch'}
# Misspelled words: {'al'}
# Misspelled words: {'yuc'}
# Misspelled words: {'hok'}
# Misspelled words: {'wei', 'hts'}
# Misspelled words: {'amazin'}
# name: Amazin, type: o_
# Misspelled words: {'kg'}
# Misspelled words: {'ofthemstandsdoing', 'sometimesone', 'itjuststops'}
# Misspelled words: {'el'}
# Misspelled words: {'slep'}
# Misspelled words: {'al'}
# Misspelled words: {'que'}
# name: Que, type: gu
# Misspelled words: {'fo'}
# Misspelled words: {'reat'}
# Misspelled words: {'antshave'}
# name: Antshave, type: oa
# Misspelled words: {'wildboar'}
# Misspelled words: {'katarína', 'albatros', 'bartíková', 'petra', 'macurová'}
# name: Katarína, type: gu
# name: Albatros, type: C
# name: Bartíková, type: ps
# name: Petra, type: pf
# name: Macurová, type: ps
# Misspelled words: {'katarína', 'bartíková', 'petra', 'macurová'}
# name: Katarína, type: gu
# name: Bartíková, type: ps
# name: Petra, type: pf
# name: Macurová, type: ps
# Misspelled words: {'ean', 'isbn'}
# name: Ean, type: pf
# name: Isbn, type: mn
# Misspelled words: {'albatros'}
# name: Albatros, type: C

# %% [markdown]
# #### Are there words glued together in the string?

# %%
for glued_word in glued_words:
    print(f"Checking glued word: {glued_word}")
    for i in range(3, min(10, len(glued_word) + 1)):
        findwords(spell, glued_word, minlength= i, maxlength=i)
# Out:
# Checking glued word: te
# Checking glued word: th
# Checking glued word: falle
# 0: 'all' at position 1 (3)
# 0: 'fall' at position 0 (4)
# Checking glued word: tr
# Checking glued word: ofs
# Checking glued word: pil
# Checking glued word: ows
# Checking glued word: sc
# Checking glued word: ina
# Checking glued word: ng
# Checking glued word: placessomething
# 0: 'lac' at position 1 (3)
# 1: 'ace' at position 2 (3)
# 2: 'som' at position 6 (3)
# 3: 'met' at position 8 (3)
# 4: 'hin' at position 11 (3)
# 0: 'lace' at position 1 (4)
# 1: 'aces' at position 2 (4)
# 2: 'cess' at position 3 (4)
# 3: 'some' at position 6 (4)
# 4: 'thin' at position 10 (4)
# 0: 'place' at position 0 (5)
# 1: 'laces' at position 1 (5)
# 2: 'thing' at position 10 (5)
# 0: 'places' at position 0 (6)
# 0: 'something' at position 6 (9)
# Checking glued word: smal
# Checking glued word: mamals
# 0: 'mam' at position 0 (3)
# 0: 'mama' at position 0 (4)
# Checking glued word: el
# Checking glued word: te
# Checking glued word: ag
# Checking glued word: gerbi
# Checking glued word: slele
# Checking glued word: nothin
# 0: 'not' at position 0 (3)
# 1: 'hin' at position 3 (3)
# 0: 'thin' at position 2 (4)
# Checking glued word: ood
# Checking glued word: ng
# Checking glued word: che
# Checking glued word: doesn
# 0: 'doe' at position 0 (3)
# 0: 'does' at position 0 (4)
# Checking glued word: hasthecame
# 0: 'has' at position 0 (3)
# 1: 'the' at position 3 (3)
# 2: 'cam' at position 6 (3)
# 0: 'hast' at position 0 (4)
# 1: 'came' at position 6 (4)
# 0: 'theca' at position 3 (5)
# Checking glued word: slele
# Checking glued word: fal
# Checking glued word: tre
# Checking glued word: itstime
# 0: 'its' at position 0 (3)
# 0: 'time' at position 3 (4)
# Checking glued word: looong
# 0: 'loo' at position 0 (3)
# Checking glued word: ned
# Checking glued word: minutesin
# 0: 'nut' at position 2 (3)
# 1: 'sin' at position 6 (3)
# 0: 'minute' at position 0 (6)
# 0: 'minutes' at position 0 (7)
# Checking glued word: livingstay
# 0: 'stay' at position 6 (4)
# 0: 'living' at position 0 (6)
# 0: 'livings' at position 0 (7)
# Checking glued word: thehippo
# 0: 'the' at position 0 (3)
# 1: 'hip' at position 3 (3)
# 0: 'hippo' at position 3 (5)
# Checking glued word: itswhole
# 0: 'its' at position 0 (3)
# 1: 'who' at position 3 (3)
# 0: 'hole' at position 4 (4)
# 0: 'whole' at position 3 (5)
# Checking glued word: jawwith
# 0: 'jaw' at position 0 (3)
# 1: 'wit' at position 3 (3)
# 0: 'with' at position 3 (4)
# Checking glued word: aroundit
# 0: 'dit' at position 5 (3)
# 0: 'round' at position 1 (5)
# 0: 'around' at position 0 (6)
# Checking glued word: smal
# Checking glued word: se
# Checking glued word: se
# Checking glued word: sleepin
# 0: 'lee' at position 1 (3)
# 1: 'pin' at position 4 (3)
# 0: 'sleep' at position 0 (5)
# Checking glued word: ba
# Checking glued word: tres
# Checking glued word: gras
# Checking glued word: ste
# Checking glued word: balanceand
# 0: 'ala' at position 1 (3)
# 1: 'and' at position 7 (3)
# 0: 'lance' at position 2 (5)
# 0: 'balance' at position 0 (7)
# Checking glued word: kilometre
# 0: 'met' at position 4 (3)
# 0: 'kilo' at position 0 (4)
# Checking glued word: le
# Checking glued word: ood
# Checking glued word: le
# Checking glued word: nde
# Checking glued word: needn
# 0: 'need' at position 0 (4)
# Checking glued word: rol
# Checking glued word: al
# Checking glued word: ful
# Checking glued word: ng
# Checking glued word: ng
# Checking glued word: flamin
# 0: 'lam' at position 1 (3)
# 1: 'ami' at position 2 (3)
# 0: 'flam' at position 0 (4)
# Checking glued word: plas
# Checking glued word: standin
# 0: 'tan' at position 1 (3)
# 1: 'and' at position 2 (3)
# 2: 'din' at position 4 (3)
# 0: 'stand' at position 0 (5)
# Checking glued word: le
# Checking glued word: ncredible
# 0: 'red' at position 2 (3)
# 1: 'dib' at position 4 (3)
# 0: 'cred' at position 1 (4)
# 0: 'edible' at position 3 (6)
# 0: 'credible' at position 1 (8)
# Checking glued word: milioooooons
# 0: 'mil' at position 0 (3)
# Checking glued word: eho
# Checking glued word: hed
# Checking glued word: onitsbodythe
# 0: 'nit' at position 1 (3)
# 1: 'its' at position 2 (3)
# 2: 'bod' at position 5 (3)
# 3: 'the' at position 9 (3)
# 0: 'nits' at position 1 (4)
# 1: 'body' at position 5 (4)
# Checking glued word: thousandsof
# 0: 'tho' at position 0 (3)
# 1: 'and' at position 5 (3)
# 0: 'thou' at position 0 (4)
# 1: 'sand' at position 4 (4)
# 0: 'thous' at position 0 (5)
# 1: 'sands' at position 4 (5)
# 0: 'thousand' at position 0 (8)
# 0: 'thousands' at position 0 (9)
# Checking glued word: apetite
# 0: 'ape' at position 0 (3)
# 1: 'pet' at position 1 (3)
# 2: 'tit' at position 3 (3)
# 0: 'petit' at position 1 (5)
# 0: 'petite' at position 1 (6)
# Checking glued word: bal
# Checking glued word: sleps
# Checking glued word: fliiiieees
# Checking glued word: sleps
# Checking glued word: tretch
# 0: 'tret' at position 0 (4)
# 1: 'etch' at position 2 (4)
# 0: 'retch' at position 1 (5)
# Checking glued word: al
# Checking glued word: yuc
# Checking glued word: hok
# Checking glued word: wei
# Checking glued word: hts
# Checking glued word: kg
# Checking glued word: ofthemstandsdoing
# 0: 'oft' at position 0 (3)
# 1: 'the' at position 2 (3)
# 2: 'hem' at position 3 (3)
# 3: 'ems' at position 4 (3)
# 4: 'tan' at position 7 (3)
# 5: 'and' at position 8 (3)
# 0: 'them' at position 2 (4)
# 1: 'hems' at position 3 (4)
# 0: 'stand' at position 6 (5)
# 1: 'doing' at position 12 (5)
# 0: 'stands' at position 6 (6)
# Checking glued word: sometimesone
# 0: 'som' at position 0 (3)
# 1: 'met' at position 2 (3)
# 2: 'mes' at position 6 (3)
# 3: 'son' at position 8 (3)
# 4: 'one' at position 9 (3)
# 0: 'some' at position 0 (4)
# 1: 'time' at position 4 (4)
# 2: 'sone' at position 8 (4)
# 0: 'times' at position 4 (5)
# 1: 'meson' at position 6 (5)
# 0: 'sometime' at position 0 (8)
# 0: 'sometimes' at position 0 (9)
# Checking glued word: itjuststops
# 0: 'top' at position 7 (3)
# 1: 'ops' at position 8 (3)
# 0: 'just' at position 2 (4)
# 1: 'stop' at position 6 (4)
# 2: 'tops' at position 7 (4)
# 0: 'stops' at position 6 (5)
# Checking glued word: el
# Checking glued word: slep
# Checking glued word: al
# Checking glued word: fo
# Checking glued word: reat
# 0: 'eat' at position 1 (3)
# Checking glued word: wildboar
# 0: 'boa' at position 4 (3)
# 1: 'oar' at position 5 (3)
# 0: 'wild' at position 0 (4)
# 1: 'boar' at position 4 (4)

# %%
for word_list in text_page['text']:
    for word in word_list.split():
        word = word.strip('.,!?()[]{}"\'').lower()
        if word not in words.words():
            print(f"Non-english word: {word}")

# %%
text_page = pd.DataFrame(text_page)
text_page.to_excel(f'excel tables/Classifier_text.xlsx', index=False)

# %% [markdown]
# #### OCR method
# Will be used when pdf method is not possible.

# %%
reader = easyocr.Reader(['en'], gpu=True)

conf = 0.40


book_image_surface = 0
book_text_surface = 0
book = 'This Is Our Piggy'
number_of_pages = len(os.listdir(f'JPGs/{book}/'))
for i in range(0, number_of_pages):

    test_img = f'JPGs/{book}/{book}_{i}.jpg'
    raw_text, results = easy_ocr(reader, test_img)

    #Compute surface of box
    results['surface'] = results[results['conf'] > conf].bbox.apply(
       lambda x: (x[2][0] - x[0][0]) * (x[2][1] - x[0][1])
    )
    

    # Read image with OpenCV (for size)
    im = cv2.imread(test_img)
    h, w, _ = im.shape
    image_surface = w * h
    book_image_surface += image_surface

    #text_area = results.surface.sum()
    #book_text_surface += text_area
    if len(results[results['conf'] > conf]) > 0: 
        text_area, number_of_boxes, geoms_area = compute_area_ocr(results[results['conf'] > conf]) 
    else: text_area, number_of_boxes, geoms_area = 0,0,[0]

    coverage = text_area / image_surface * 100
    #number_of_boxes = len(results[~results['surface'].isnull()])
    print(f"Page {i} coveres {coverage:.2f}% of the page and has {number_of_boxes} boxes.")

    # Plotting the image and boxes
    fig, ax = plt.subplots(figsize=(10, 14))
    im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    ax.imshow(im_rgb)

    for _, row in results.iterrows():
        if row.conf > conf:
            box = row['bbox']
            rect_x = box[0][0]
            rect_y = box[0][1]
            rect_w = box[2][0] - box[0][0]
            rect_h = box[2][1] - box[0][1]

            rect = patches.Rectangle(
                (rect_x, rect_y),
                rect_w,
                rect_h,
                linewidth=1,
                edgecolor='red',
                facecolor='none'
            )
            ax.add_patch(rect)

    ax.set_title(f"Page {i} — Coverage: {coverage:.2f}%, Boxes: {number_of_boxes}")
    plt.axis('off')
    plt.show()

# %%
book_percentage = book_text_surface/book_image_surface*100
print(f'Percentage of text in {book}: {book_percentage} %')

# text from PDF
book_text_path = f'Plain text/{book}.txt'
f = open(book_text_path)
text = f.read()
number_of_words = len(text.split())
print(f'Number of words: {number_of_words}')
average_number_of_words = number_of_words/number_of_pages
print(f'Average number of words per page: {average_number_of_words}')
# Out:
# Percentage of text in Shapes and Patterns in Nature: 9.9135730381641 %
# Number of words: 2882
# Average number of words per page: 137.23809523809524

# %%
import pymupdf
from pypdf import PdfReader

### From: https://stackoverflow.com/questions/52346942/how-to-replace-delete-text-from-a-pdf-using-python

book = 'I Am in Love With My Bicycle'
file_path = f"PDFs/{book}.pdf"
doc = pymupdf.open(file_path) # open a document

reader = PdfReader(file_path)

for i in range(0,4):
    page = doc.load_page(i)
    print(f'Page {i}')

    lines = reader.pages[i].extract_text().split('\n')
    print(lines)
    for line in lines:
        draft = page.search_for(line)
        try:
            for rect in draft:
                annot = page.add_redact_annot(rect)
                page.apply_redactions()
                page.apply_redactions(images=fitz.PDF_REDACT_IMAGE_NONE)
        except: print('No Text')        
    
doc.save(f"{book}_without_text.pdf", garbage=3, deflate=True)
# Out:
# Page 0
# ['I AM IN LOVE WITH MY', 'mAgda gArgulákOvá & MArie urbánkOVá', 'mAgda gArgulákOvá & MArie urbánkOVáI AM IN LOVE WITH MY ', 'IF YOU HAVE A BIKE, GET ON! If you haven’t – we’ll lend you one! ', 'Then let us go out on the lanes and roads, through the mud and puddles. ', 'A bike takes you anywhere you fancy. On a bike, you’re free and unstoppable. ', 'Just pedal… and understand what’s going on around you. Whether you’re an ', 'avid cyclist or just starting out, it’s good to know a few things about bikes – such ', 'as which is the right one for you, how high to set your saddle, and what you ', 'should never, ever do on a bike. So, why not read all about it – in this book! ', 'It may be small, but it’s packed with fun and information. You’ll learn why your ', 'helmet should be a good fit, as well as lots of other things about bikes and ', 'cycling. You’ll take a ride in a fun bicycle maze and get to know for yourself why ', 'a bike sometimes needs mudguards. But enough of this talk! Get on your bike ', 'and let’s be on our way!  ', 'www.albatrosmedia.eu', '© Designed by B4U Publishing,  ', 'member of Albatros Media Group, 2024. ', 'Author: Magda Garguláková', 'Illustrations © Marie Urbánková, 2024', 'All rights reserved. ', 'b4u publishing', 'FSC logo']
# No Text
# No Text
# No Text
# Page 1
# ['Because cycling is great! Because ', 'the wheels go round as the world ', 'goes by. Because cycling puts colour ', 'in your cheeks, and that makes life ', 'jollier. Also because: ', 'ANYONE CAN DO IT ', 'IT’S FUN ', 'IT STRENGTHENS THE LEGS AND SHARPENS THE SENSES ', 'IT’S ECOLOGICAL ', 'IT GETS YOU WHERE YOU NEED TO BE… ', 'IT’S QUICK ', ' ', 'WHY CYCLE? ', 'AND HEALTHY ', 'Anywhere you can think of. ', 'Anywhere you need or want to be. ', 'Climb on and off you go!  ', '... T O SEE FRIENDS', '... JUST ', 'FOR  THE  RIDE', '... T O THE SHOPS ', '... TO THE ', 'WOODS', '... TO GRANDMA’S', '... T O THE COUNTRY', 'WHERE CAN YOU CYCLE TO? ', 'SCHOOL', 'SHOP', '... TO SCHOOL', '... T O THE PLAYGROUND', '... T O THE LIDO']
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# Page 2
# ['So here it is – the bike, or bicycle! ', 'Mine is blue, and I love it. Every proper ', 'cyclist looks after their bike and puts on ', 'it everything it needs. A well-kept, well-', 'equipped bike is always a good ride! ', 'Come with me and I’ll show you my bike ', 'up close. ', 'chain A very ', 'important part ', 'of a bike. As ', 'you pedal, the ', 'chain turns. ', 'And away you ', 'go! ', 'TOOLS A punctured tyre, a fallen ', 'chain, a nut that needs tightening… ', 'With this little bag of basic tools, ', 'such a mishap won’t set you back.  ', 'A GLUE B PATCHES C SANDPAPER ', 'D TYRE IRON FOR INNER-TUBE CHANGE', 'E HAND PUMP  ', 'F MULTI-FUNCTION TOOL', 'frame Without this, the parts of the ', 'bike wouldn’t hold together.  ', 'SaDdLe Held in place by a seat ', 'post. Make sure yours is right for ', 'you – your backside will be glad.  ', 'MUDGUARDS ', 'These stop ', 'mud from the ', 'wheels from ', 'getting on ', 'your clothes.  ', 'DERAILLEUR  This comprises several ', 'sprockets driven by a chain. You ', 'change its gears, to climb hills ', 'more easily or go faster on the ', 'flat, by engaging a lever on the ', 'handlebars.  ', 'A BIKE UP CLOSE  ', '1', '1', '3', '3', '8', '8', '4', '4', '9', '6', '6', '2', '2', 'A B C', 'DE', 'F', '12', '11', '5', '5', '13', '13', '13', '13', '16', 'EXTRA-SOFT', 'SHAPED', 'EXTRA-WIDE', 'MINIMALIST', 'HANDLEBARS We hold them tight as ', 'we use them to control the front ', 'wheel, and with it our direction. ', 'bell An important addition. ', 'A ring on the bell lets the world ', 'know you are coming. But never ', 'ring just for fun, only when you ', 'need to.  ', 'PEDaLs We step on these ', 'to get the wheels turning ', 'and the bike moving. ', 'WATER BOTTLE A must ', 'for every cyclist. A tired, ', 'hungry and thirsty cyclist ', 'has no place on the ', 'road.  ', 'lights These light ', 'your way to keep ', 'you safe. Two are ', 'required – white ', 'at the front, red ', 'at the back. They ', 'must be on or ', 'flashing whenever ', 'visibility is poor. ', 'BRakes Brakes save lives! ', 'A bike has a front and a ', 'rear brake, controlled by ', 'levers on the handlebars. ', 'Children’s bikes are ', 'braked by back-', 'pedalling.  ', 'TACHOMETeR If you want ', 'to know your speed ', 'or how far you ', 'have travelled, ', 'get yourself a ', 'tachometer or ', 'cyclocomputer. ', 'BICYCLE  ', 'LOCK Strong ', 'and heavy-', 'duty, its job ', 'is to protect ', 'your bike from ', 'thieves. ', 'REFLECTORS These reflect ', 'light, mainly from car ', 'headlights. It is mandatory ', 'for bikes to have them – in ', 'wheel spokes, on pedals, ', 'and at the front (white) ', 'and rear (red). ', '3', '8', '4', '4', '9', '9', '12', '13', '12', '15', '15', '11', '11', '11', '11', '13', '13', '13', '16', '7', '7', '10', '10', '1414', 'spO rt', '123', 'km', '/H', 'WHEELS The two wheels are each contained ', 'in a tyre. Tyres come in different widths, are ', 'smooth or treaded, and must be properly ', 'inflated (using a hand ', 'pump).  ', 'VALVE ', 'for tyre inflation']
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# Page 3
# ['UTILITY BIKE If you are dressed for ', 'the office or theatre, this elegant bike ', 'is for you. Its low frame makes it easy ', 'to get on and off. It has mudguards, ', 'a basket for all your essentials and ', 'a comfortable, extra-soft saddle.  ', 'CHOOSE YOUR BIKE', 'Bikes come in many kinds. Some are better for whizzing along roads, ', 'others for hopping over roots on a woodland track. This is why bikes ', 'come with different tyre thicknesses, frame widths and handlebar ', 'shapes. To choose the right bike for you, decide what you want it to do. ', 'RACING BIKE If you like long rides ', 'that test your endurance, then a ', 'racer (also known as a road bike) ', 'is for you. It has large, narrow ', 'wheels, a slim frame and curved, ', 'drop handlebars. Pedals with ', 'treads, clips and straps allow ', 'you to really step on it! Whizz… ', 'and you’re gone. ', 'MOUNTAIN BIKE This heavier, ', 'bulkier bike looks altogether ', 'more rugged. Its deep tyre ', 'treads allow it to cope with ', 'uneven terrain. It won’t let ', 'you down on woodland ', 'tracks, and stones and mud ', 'are like child’s play… This all-', 'terrain bike is quite at home ', 'on roads too. ', 'TANDEM This bike is a dream! ', 'It looks great, is fun to ride, ', 'and you don’t have to pedal ', 'alone! Plus, as you go, you ', 'and your partner can have ', 'a nice chat.   ', 'BEGINNING CYCLISTS', 'CHILD’S SEAT TRAILER TRAINER HANDLE ', 'BMX – FREESTYLE If you are ', 'drawn to ramps, stairs, tricks and ', 'acrobatics, get yourself a BMX. It ', 'has small wheels, a low frame and ', 'wide handlebars. You can jump ', 'and spin about on it, provided that ', 'you practise first.    ', 'ELECTRIC BIKE It may ', 'look ordinary, but it has ', 'something special. It makes ', 'a purring or buzzing ', 'because it has a built-', 'in electric motor to help ', 'you pedal. Good, isn’t it? ', 'What isn’t so good is the ', 'greater weight. If the battery ', 'runs out, you may have ', 'a problem on your hands. ', 'FOLDING BIKE A bike the size ', 'of a suitcase. It has a low ', 'frame and small wheels, ', 'and anyone can ride it. It is ', 'especially practical for short ', 'rides around town. If you ', 'wish to take it into a shop, ', 'no problem: folded up, it ', 'handles like a big bag.   ', 'Cyclists are made, not born. Every cyclist must start somewhere, ', 'and the vast majority of us begin as a passenger. It’s great to be ', 'driven, and to look around without having to pedal. Even so, every ', 'child soon wants a bike of their own. Before this can happen, they ', 'experience some of these things:    a child an animal a toy', 'WHO/WHAT YOU CAN CARRY', 'SIDE CARRIER    ', 'BALANCE BIKE ', 'HURRAY! I’M RIDING ', 'ON MY OWN! ', 'VRRR', 'VRRR', 'SEAT BOX ']
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text
# No Text

# %%
from pypdf import PdfReader

doc = PdfReader("PDFs/Shapes and Patterns in Nature.pdf")
doc.get_fields()
# Out:
# {}

# %%
doc.page_layout

# %%
book = 'Atlas of Cats'
pdf_file = f'PDFs/{book}.pdf'
doc = fitz.open(pdf_file)

page = doc[5]

text_dict = defaultdict(list)
last_font = None


for block in text_instances:
    if "lines" in block:
        for line in block["lines"]:
            for span in line["spans"]:
                font = span["font"]
                size = span["size"]
                font_size = (font, size)
                if font_size != last_font:
                    text_dict[font_size].append('\n' + span["text"])
                    last_font = font_size
                else:
                    text_dict[font_size].append(span["text"])

# %%
print(text_dict.keys())
' '.join(text_dict[('MrDodo-LightRounded', 12.0)])
# Out:
# dict_keys([('MrsWhite', 14.0), ('MrsWhite', 15.0), ('BiscuitChicken', 15.0), ('MrDodo-LightRounded', 12.0), ('BiscuitChicken', 10.0), ('BiscuitChicken', 20.0), ('MrDodo-RegularRounded', 20.0), ('BiscuitChicken', 20.124610900878906), ('BiscuitChicken', 18.0), ('BiscuitChicken', 48.0), ('MrsWhite', 18.0), ('MrDodo-RegularRounded', 12.0)])
# "\nRomper \nYou may pet me whenever \n I feel like it. \nAny household cat that has the appearance and temperament \n described above can be called a European shorthair, though it's  true that such a cat is pretty hard to find in village squares \n or animal shelters. \nJust like wild animals defend their territory, so can I fight for  the right to rule my home. Over time, I may come to accept a  new cat or dog friend, but it usually takes me a while. After all,  I must make sure that my human pack still loves me since our  house is so crowded all of a sudden!  \nEach one of us is unique. That's because we are not  usually bred, and unlike other breeds don’t have to meet  strict rules on personality and temperament. We tend to  be smart (naturally), playful, and full of energy, but not  crazy hotheads. An afternoon snooze on a window sill?  Yes, please. What we really love, though, is hunting — our \n hunting instincts are very strong. \n1. Chinese Li Hua 2. Australian Mist 3. Desert Lynx Cat  4. American Shorthair  5. Mojave Spotted Cat 6. Highlander Shorthair The first humans I ever befriended were  the Roman soldiers I accompanied on  their journey around Europe, protecting  their food supplies from hungry rodents  and cheeky birds. I can't even describe  the respect they showed me! Over time,  I stopped being a wild predator and  turned into a loyal domestic companion,  as well as the terror of all mice that  infest pantries and storerooms. "
