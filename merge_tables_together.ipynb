# %%
import pandas as pd

# %%
def clean_title_fun(title):
    ''' Function that unifies book names'''
    if title is None or pd.isna(title):
        return None  

    return (str(title).lower()
                   .replace('´', "'")
                   .replace('?', '')
                   .replace('!', '')
                   .replace(',', '')
                   .replace('&', 'and')
                   .replace('’', "'"))

# %%
# Load tables
prehled_vse = pd.read_excel('excel tables/Přehled vše2_upraveno.xlsx')  
albatrosmedia = pd.read_excel('excel tables/Scraped Data AlbatrosMedia Series.xlsx')
prehled_vse['Sold To'] = prehled_vse['Sold To'].apply(lambda x: None if 'Not found' in str(x) else x)
albatrosmedia['Sold To'] = albatrosmedia['Sold To'].apply(lambda x: None if 'Not found' in x else x)

# Create column cleaned_titles - lower case, unified  
prehled_vse['cleaned_titles'] =  prehled_vse['Název knihy'].apply(clean_title_fun)

# Take URL as index
url_prehled = pd.Index(prehled_vse['URL'])
url_albatrosmedia = pd.Index(albatrosmedia['URL'])

# Find indices that are not in 'prehled vse'
missing_url = url_albatrosmedia.difference(url_prehled)
common_url = url_albatrosmedia.intersection(url_prehled)

# From Albatros rows only with the missing urls
albatros_missing = albatrosmedia[albatrosmedia['URL'].isin(missing_url)]

# %% [markdown]
# #### How many duplicities

# %%
albatros_missing['Book Name'].value_counts()
# Out:
# Book Name
# Seasons                                                      2
# A Big Book of Poison                                         1
# Rainbow Unicorns                                             1
# Observing the Plants of the Forest with Hansel and Gretel    1
# On the Go                                                    1
#                                                             ..
# Everything You’ve Ever Wanted to Know About The Moon         1
# Fashion HiStory                                              1
# Field Buddies                                                1
# Forests of the World                                         1
# Why Won’t You Flower?                                        1
# Name: count, Length: 143, dtype: int64

# %% [markdown]
# ### Replace Book Names with the ones that are in CRM

# %%
# Replace Book Names
# Format (old_book_name, illustrator): new_book_name
fix = {('Anthill', 'Tomáš Tůma'):'Anthill (How Animals Live)', ('Arnie’s Construction', 'Martin Sodomka'): 'Arnie & Construction', 
      ('Arnie’s Workshop', 'Martin Sodomka'):'Arnie & Workshop', ('Beehive', 'Tomáš Tůma'):'Beehive (How Animals Live)', ('Childhood of Famous People', 'Tomáš Tůma'): 'Childhood of Famous People: from Mozart to Einstein',
      ('Christmas all around the World', 'Ocean Hughes'):'Christmas (Reusable Sticker Book)', ('Christmas around the World', 'Mária Nerádová'): 'Christmas around the World (Children Around the World)',
      ('Don´t Be Afraid', 'Jakub Kaše;Lukáš Urbánek'): 'Don\'t Be Afraid', ('Everything You’ve Ever Wanted to Know About The Moon', 'Inna Chernyak'):'Everything You\'ve Ever Wanted to Know About The Moon', 
      ( 'History of Warriors','Kateřina Wagnerová Hikade;Tomáš Pernický;Ondřej Dolejší'):'Warriors', ('Numbers', 'Marie Urbánková'):'Numbers (Got It)',
      ('Numbers', 'Julie Cossette'): 'Numbers (Learning Wheel)', ('Shapes', 'Veronika Kopečková'): 'Shapes (Choose and Learn)',
      ('The Stories of Interesting Towns and Cities', 'Jakub Cenkl'): 'The Stories of Towns and Cities', ('Urban Legends: „True“ Horror Stories from City Streets', 'Miloš Mazal'):'Urban Legends: True Horror Stories from City Streets',
      ('What’s Your Craft?', 'Milan Starý'): 'What\'s Your Craft?', ('What’s Your Job?', 'Milan Starý'):'What\'s Your Job?',
      ('Why Paintings Don´t Need Titles', 'Jiří Franta'):'Why Paintings Don\'t Need Titles', ('Why Won’t You Flower?', 'Katarína Macurová'): 'Why Won\'t You Flower?',
      ('Seasons', 'Julie Cossette'):'Seasons (Learning Wheel)', ('Seasons', 'Veronika Kopečková'): 'Seasons (Choose and Learn)', 
      ('Town', 'Alexandra Májová Hetmerová'): 'Town (Yesterday and Today)'}
for (orig_book_name, ill), new_book_name  in fix.items():
    albatros_missing.loc[(albatros_missing['Book Name'] == orig_book_name) & (albatros_missing['Illustrators Scraped'] == ill), 'Book Name'] = new_book_name

albatros_missing['cleaned_titles'] =  albatros_missing['Book Name'].apply(clean_title_fun)
# Out:
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/1405651939.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albatros_missing['cleaned_titles'] =  albatros_missing['Book Name'].apply(clean_title_fun)

# %% [markdown]
# #### Match missing Titles with Prehled vse

# %%
# Take Book Name as Index
title_prehled = pd.Index(prehled_vse['cleaned_titles'])
book_albatrosmedia = pd.Index(albatros_missing['cleaned_titles'])

not_found_titles = book_albatrosmedia.difference(title_prehled)
found_titles = book_albatrosmedia.intersection(title_prehled)

# Titles that are not in 'prehled vse'
print(not_found_titles)
print(len(not_found_titles))
# Out:
# Index(['a day of colours', 'alliance of the brave', 'amazing domestic animals',
#        'an atlas of incredible islands: real stories of unreal lands',
#        'an explanatory dictionary', 'atlas of planet earth for children',
#        'characters in literature and their stories', 'frostina',
#        'get ready for christmas', 'get ready for halloween', 'girl power',
#        'hope it turns out well', 'magic world of unicorns',
#        'mandalas diamond art', 'mum and dad have split up',
#        'mum dad i want to be president', 'on the go',
#        'one ball two mice and what came next', 'parrots are great but…',
#        'rabbits are great', 'rainbow unicorns',
#        'rob memory doesn't want to leave',
#        'scatterbrain the bogey doesn't want to leave',
#        'shush do you hear the silence', 'smart scribbles', 'superstitions',
#        'the book of disappearing plants', 'the life of a butterfly', 'the sky',
#        'the snipkins', 'the year in colours', 'we're only human',
#        'what goes on in a town', 'who can do without a desk',
#        'whose table is that'],
#       dtype='object', name='cleaned_titles')
# 35

# %% [markdown]
# #### Tuple (Scraped Book Title, Illustrator) -> Book Title in CMR table

# %%
# Add additional info to excel table prehled vse
for found_title in found_titles: 
    print(albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'URL'].values[0])
    print(prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'URL'])
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'URL'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'URL'].values[0]
   
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Illustrators Scraped'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Illustrators Scraped'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Age'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Age'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Book Parametes'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Book Parametes'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Sold To'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Sold To'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Description'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Description'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Authors Scraped'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Authors Scraped'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Scraping'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Scraping'].values[0]
    
    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Book Name Scraping Original'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Book Name Scraping Original'].values[0]

    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Scraping'] = True

    prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Category'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Category'].values[0]

                                                                          
    
    # for (columnName, columnData) in albatros_missing[(albatros_missing['cleaned_titles']  == found_title)].items():
    #     print(f'{str(columnName)}: {str(columnData.values[0])}')
    #     prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, str(columnName)] = str(columnData.values[0])
# Out:
# https://www.albatrosmedia.eu/book/a-big-book-of-poison/
# 14    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-big-book-of-snow-and-ice/
# 15    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-big-book-of-the-dark/
# 16    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-big-book-of-underground/
# 17    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-bug-hotel/
# 22    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-curious-dragon-and-the-seasons/
# 25    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-world-atlas-of-ghosts-and-friends/
# 35    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-year-in-the-garden/
# 36    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/a-year-in-the-woods/
# 37    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/adventure-geometry-the-cube/
# 40    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/adventure-geometry-the-sphere/
# 41    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/adventures-around-the-world-with-lily-the-explorer/
# 42    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/adventures-of-crime-and-punishment/
# 43    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/all-about-the-egg/
# 48    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/all-nine-dormice-in-the-house/
# 53    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/all-that-flies-with-or-without-feathers/
# 55    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/all-that-floats-with-or-without-fins/
# 56    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/animal-colours/
# 77    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/animal-patterns/
# 82    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/animals/
# 84    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/anthill/
# 109    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/are-you-careful-enough-a-guide-for-little-hotheads/
# 111    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/arnies-construction/
# 112    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/arnies-workshop/
# 113    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/atlas-of-prehistoric-animals/
# 130    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/beehive/
# 146    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/body-language-and-how-to-read-it/
# 155    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/bridges/
# 157    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/can-you-behave-etiquette-for-little-rascals/
# 163    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/cars-2/
# 164    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/childhood-of-famous-people-from-mozart-to-einstein/
# 168    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/christmas-3/
# 174    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/christmas-around-the-world/
# 176    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/city-at-night/
# 179    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/colours-2/
# 188    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/columbus-pigeon/
# 194    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/delicacies-from-around-the-world-with-chef-vincent/
# 205    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/desert/
# 206    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/do-you-know-how-things-are-made/
# 214    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/dont-be-afraid/
# 220    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/everyday-life-at-school/
# 244    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/everything-youve-ever-know-about-the-moon/
# 245    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/fashion-story/
# 252    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/field-buddies/
# 253    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/forests-of-the-world/
# 258    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/frozen/
# 268    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/fruits-and-veggies/
# 271    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/mission-heal-the-body/
# 294    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/hide-and-seek-in-nature/
# 299    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/history-of-warriors/
# 821    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/home/
# 304    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-children-celebrate-holidays-around-the-world/
# 313    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-children-live-around-the-world/
# 314    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-plants-talk/
# 331    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-things-are-made/
# 338    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-to-build-a-car/
# 345    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-to-build-a-house-2/
# 342    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-to-build-a-motorbike/
# 343    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-to-build-a-plane/
# 344    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-to-build-a-railway/
# 346    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/how-to-make-a-gallery/
# 350    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/im-not-afraid-of-the-dark/
# 402    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/inventions/
# 400    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/joey-learns-to-tie-his-shoelaces/
# 408    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/jungle/
# 410    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/kate-learns-to-tie-her-shoelaces/
# 411    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/laughter-and-crying/
# 420    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/let-me-tell-you-something-johan/
# 424    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/lets-play-outside/
# 427    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/light-and-darkness/
# 436    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/little-red-riding-hood-3/
# 469    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/momo-and-lily/
# 494    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/my-day/
# 499    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/my-little-red-book/
# 505    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/not-as-scary-as-it-looks/
# 520    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/numbers-2/
# 523    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/observing-the-plants-of-the-forest-with-hansel-and-gretel/
# 533    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/prehistory-2/
# 593    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/mission-save-the-planet/
# 622    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/seasons-2/
# 628    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/seasons/
# 627    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/seasons-and-weather/
# 629    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/shadow-play/
# 635    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/shapes/
# 637    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/shortcuts/
# 646    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/teddy-in-the-garage/
# 672    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/teddy-in-the-kitchen/
# 674    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/teddy-on-the-farm/
# 675    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/the-big-book-of-peeing/
# 688    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/the-origins-of-sports/
# 717    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/the-stories-of-towns-and-cities/
# 730    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/the-story-of-the-car/
# 735    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/the-world-of-animals/
# 754    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/things-not-seen-by-the-naked-eye/
# 758    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/things-that-go-2/
# 759    https://www.albatrosmedia.eu/book/things-that-go/
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/things-to-experience-before-you-start-school/
# 760    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/town-2/
# 788    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/trains/
# 792    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/unlikely-friendships-in-nature/
# 809    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/urban-legends-true-horror-stories-from-city-streets/
# 813    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/water-cycle-adventure/
# 824    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/waters-of-the-world/
# 825    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/were-off-to-the-forest/
# 831    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/what-will-i-be/
# 848    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/whats-your-craft/
# 852    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/whats-your-job/
# 853    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/which-is-the-right-ball/
# 863    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/why-paintings-dont-need-titles/
# 881    NaN
# Name: URL, dtype: object
# https://www.albatrosmedia.eu/book/why-dont-you-flower/
# 884    NaN
# Name: URL, dtype: object
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/2711440511.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   prehled_vse.loc[prehled_vse['cleaned_titles'] == found_title, 'Scraping'] = albatros_missing.loc[albatros_missing['cleaned_titles'] == found_title, 'Scraping'].values[0]

# %%
albatros_missing[albatros_missing['cleaned_titles'].isin(not_found_titles)]
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 10             10          12
# 34             34          40
# 36             36          42
# 41             41          47
# 42             42          49
# 80             80          86
# 110           110         114
# 178           178         180
# 186           186         188
# 187           187         189
# 190           190         192
# 209           209         210
# 316           316         316
# 319           319         319
# 329           329         329
# 330           330         332
# 355           355         359
# 359           359         362
# 367           367         370
# 386           386         388
# 388           388         390
# 391           391         393
# 397           397         397
# 416           416         416
# 419           419         419
# 430           430         431
# 445           445         448
# 453           453         456
# 467           467         470
# 468           468         471
# 490           490         493
# 543           543         547
# 552           552         553
# 568           568         568
# 578           578         578
#
#                                                    URL  \
# 10   https://www.albatrosmedia.eu/book/a-day-of-col...
# 34   https://www.albatrosmedia.eu/book/alliace-of-t...
# 36   https://www.albatrosmedia.eu/book/amazing-dome...
# 41   https://www.albatrosmedia.eu/book/an-atlas-of-...
# 42   https://www.albatrosmedia.eu/book/an-explanato...
# 80   https://www.albatrosmedia.eu/book/atlas-of-pla...
# 110  https://www.albatrosmedia.eu/book/characters-i...
# 178        https://www.albatrosmedia.eu/book/frostina/
# 186  https://www.albatrosmedia.eu/book/get-ready-to...
# 187  https://www.albatrosmedia.eu/book/get-ready-to...
# 190      https://www.albatrosmedia.eu/book/girl-power/
# 209  https://www.albatrosmedia.eu/book/hope-it-turn...
# 316  https://www.albatrosmedia.eu/book/magic-world-...
# 319  https://www.albatrosmedia.eu/book/mandalas-dia...
# 329  https://www.albatrosmedia.eu/book/mom-and-dad-...
# 330  https://www.albatrosmedia.eu/book/mum-dad-i-wa...
# 355       https://www.albatrosmedia.eu/book/on-the-go/
# 359  https://www.albatrosmedia.eu/book/one-ball-two...
# 367  https://www.albatrosmedia.eu/book/parrots-are-...
# 386  https://www.albatrosmedia.eu/book/rabbits-are-...
# 388  https://www.albatrosmedia.eu/book/rainbow-unic...
# 391  https://www.albatrosmedia.eu/book/rob-memory-d...
# 397  https://www.albatrosmedia.eu/book/scatterbrain...
# 416  https://www.albatrosmedia.eu/book/shush-do-you...
# 419  https://www.albatrosmedia.eu/book/smart-scribb...
# 430   https://www.albatrosmedia.eu/book/superstitions/
# 445  https://www.albatrosmedia.eu/book/the-book-of-...
# 453  https://www.albatrosmedia.eu/book/the-life-of-...
# 467         https://www.albatrosmedia.eu/book/the-sky/
# 468    https://www.albatrosmedia.eu/book/the-snipkins/
# 490  https://www.albatrosmedia.eu/book/the-year-in-...
# 543  https://www.albatrosmedia.eu/book/were-only-hu...
# 552  https://www.albatrosmedia.eu/book/what-goes-on...
# 568  https://www.albatrosmedia.eu/book/who-can-do-w...
# 578  https://www.albatrosmedia.eu/book/whose-table-...
#
#            Illustrators Scraped   Age  \
# 10           Veronika Dvořáková   3-5
# 34                  Jiří Franta  9-12
# 36             Radka Martincová   6-8
# 41                    Adam Wolf  9-12
# 42             Michaela Casková   3-5
# 80                   Tomáš Tůma  9-12
# 110                 Jakub Cenkl   6-8
# 178               Zuzana Čupová   6-8
# 186                Ocean Hughes   3-5
# 187                 Anuki Lopéz   3-5
# 190           Attanasio Fabiana   3-5
# 209                    Nikkarin   6-8
# 316               Liliana Perez   3-5
# 319             Andrea Brázdová   6-8
# 329                 Lenka Blaze   6-8
# 330            Martin Hanschild   6-8
# 355             Williams Gareth   3-5
# 359          Veronika Dvořáková   3-5
# 367                   Adam Wolf   6-8
# 386                   Adam Wolf   6-8
# 388               Liliana Perez   3-5
# 391           Lucia Derčalíková   6-8
# 397           Lucia Derčalíková   6-8
# 416              Dorota Šebková   6-8
# 419              Táňa Sekerková   3-5
# 430                 Lukáš Figeľ  9-12
# 445            Eliška Podešvová  9-12
# 453                    Linh Dao   6-8
# 467            Aksana Rashetska   6-8
# 468  Alexandra Májová Hetmerová   6-8
# 490           Magdalena Konečná   6-8
# 543            Magdalena Rutová   6-8
# 552               Gabriela Hloz   6-8
# 568               Marcel Králik   3-5
# 578               Marcel Králik   3-5
#
#                                         Book Parametes Sold To  \
# 10             Size 200 x 200 mm, 7 spreads, boardbook    None
# 34              Size 215 × 280 mm, 68 pages, hardcover    None
# 36              Size 215 x 280 mm, 64 pages, hardcover    None
# 41              Size 240 x 320 mm, 64 pages, hardcover    None
# 42              Size 233 × 187 mm, 96 pages, hardcover    None
# 80   Size 230 × 260 mm, widespreaded 460 × 520 mm, ...    None
# 110             Size 215 × 280 mm, 64 pages, hardcover    None
# 178            Size 165 × 235 mm, 56 pages,  hardcover    None
# 186  Size 240 x 215 mm, 16 pages + blister with com...    None
# 187  Size 240 x 215 mm, 16 pages + blister with com...    None
# 190  Size 237 × 306, 24 pages + 8 sticker sheets, s...    None
# 209            Size 210 × 260 mm, 100 pages, paperback    None
# 316  Size 237 × 306, 24 pages + 8 sticker sheets, s...    None
# 319  Size 240 x 215 mm, 16 pages, 1 tattoo sheet + ...    None
# 329            Size 165 x 235 mm, 176 pages, paperback    None
# 330             Size 215 × 280 mm, 48 pages, hardcover    None
# 355  Size 280 x 210 mm; 6 backgrounds + 4 sticker s...    None
# 359            Size 200 x 200 mm, 7 spreads, boardbook    None
# 367             Size 215 x 260 mm, 40 pages, hardcover    None
# 386             Size 215 x 260 mm, 40 pages, hardcover    None
# 388  Size 280 x 210 mm; 6 backgrounds + 4 sticker s...    None
# 391             Size 215 x 260 mm, 32 pages, hardcover    None
# 397             Size 215 x 260 mm, 32 pages, hardcover    None
# 416             Size 220 x 220 mm, 32 pages, hardcover    None
# 419    PIPASIK, size 210 x 210 mm, 48 pages, paperback    None
# 430             Size 230 x 330 mm, 48 pages, hardcover    None
# 445             Size 215 x 280 mm, 72 pages, hardcover    None
# 453             Size 215 x 260 mm, 32 pages, hardcover    None
# 467             Size 240 x 310 mm, 72 pages, hardcover    None
# 468      Size 220 x 220 mm, 10 spreads, novelty format    None
# 490             Size 240 x 320 mm, 32 pages, hardcover    None
# 543            Size 170 x 220 mm, 120 pages, hardcover    None
# 552       Size 240 x 310 mm, 9 spreads, novelty format    None
# 568      Size 220 x 220 mm, 12 spreads, novelty format    None
# 578      Size 220 x 220 mm, 12 spreads, novelty format    None
#
#                                            Description  \
# 10   Learn and talk\nThere are so many colours, mak...
# 34   Seventh-grader Thomas Malcolm is a hero in his...
# 36   Did you know that sows sing lullabies, bees da...
# 41   Some islands appear on ancient maps but vanish...
# 42   What do words like home, snow, or teddy bear r...
# 80   An Exploration of Earth’s Wonders, From Its Co...
# 110  Deep in the forest, next to the tallest spruce...
# 178  A tiny frost fairy named Frostina, living righ...
# 186  Safe, dermatologically tested, and compliant w...
# 187  Get Ready for Halloween: Glow in the Dark Tatt...
# 190  Embark on an empowering adventure where kids c...
# 209  This book presents 45 real-life dilemmas—bully...
# 316  Thanks to this title children discover and cre...
# 319  Get ready to bring stunning mandalas to life w...
# 329  Divorce can be confusing, painful, and full of...
# 330  Big Dreams, Big Ambitions, and the Path to Suc...
# 355  This thrilling sticker activity book invites k...
# 359  Learn and talk\nOnce upon a time there was a b...
# 367  Almost every child wishes to have a pet at hom...
# 386  It’s Great to Have a Pet But…\nPerhaps all of ...
# 388  Reusable Activity Sticker Books\nStep into a m...
# 391  • Relatable and Fun: Engaging stories turn for...
# 397  Her thoughts digress and wander, she can’t con...
# 416  Silence can be peaceful, awkward, mysterious, ...
# 419  Smart Scribbles is a creative workbook for the...
# 430  Black Cats, Broken Mirrors, and the Magic We C...
# 445  Once-thriving plants are vanishing from our la...
# 453  A Hairy Caterpillar’s Tiny Struggles and the B...
# 467  What is the sky—just the blue above us, or som...
# 468  A Child’s World in Simple Words, Big Feelings,...
# 490  Nature’s Wonderful Colours\nWatch the Seasons ...
# 543  This unconventional dictionary is all about us...
# 552  • Track the Characters: Uncover their hidden s...
# 568  • 10 profession and the working environment: U...
# 578  When a person works, they have lots of things ...
#
#                                              Book Name  \
# 10                                    A Day of Colours
# 34                               Alliance of the Brave
# 36                            Amazing Domestic Animals
# 41   An Atlas of Incredible Islands: Real stories o...
# 42                           An Explanatory Dictionary
# 80                  Atlas of Planet Earth for children
# 110         Characters in Literature and Their Stories
# 178                                           Frostina
# 186                            Get Ready for Christmas
# 187                            Get Ready for Halloween
# 190                                         Girl Power
# 209                            Hope It Turns Out Well!
# 316                            Magic World of Unicorns
# 319                               Mandalas Diamond Art
# 329                          Mum and Dad Have Split up
# 330                  Mum! Dad! I Want to be President!
# 355                                          On the Go
# 359              One Ball, Two Mice and What Came Next
# 367                            Parrots Are Great, but…
# 386                                  Rabbits Are Great
# 388                                   Rainbow Unicorns
# 391                  Rob Memory Doesn’t Want to Leave!
# 397       Scatterbrain the Bogey Doesn’t Want to Leave
# 416                    Shush! Do you hear the silence?
# 419                                    Smart Scribbles
# 430                                      Superstitions
# 445                    The Book of Disappearing Plants
# 453                            The Life of a Butterfly
# 467                                            The Sky
# 468                                       The Snipkins
# 490                                The Year in Colours
# 543                                   We’re Only Human
# 552                             What Goes On in a Town
# 568                         Who can do without a desk?
# 578                               Whose table is that?
#
#                               Authors Scraped  Scraping  \
# 10                       Magda N. Garguláková      True
# 34                                Ester Stará      True
# 36                            Ester Dobiášová      True
# 41                                 Radek Malý      True
# 42                            Olga Stehlíková      True
# 80                            Oldřich Růžička      True
# 110                       Štěpánka Sekaninová      True
# 178                           Kateřina Čupová      True
# 186                               Joli Hannah      True
# 187                               Joli Hannah      True
# 190                               Joli Hannah      True
# 209                               René Nekuda      True
# 316                               Joli Hannah      True
# 319                           Andrea Brázdová      True
# 329                               Lenka Blaze      True
# 330                          Bohdana Jarošová      True
# 355                               Joli Hannah      True
# 359                          Helena Haraštová      True
# 367                       Štěpánka Sekaninová      True
# 386                       Štěpánka Sekaninová      True
# 388                               Joli Hannah      True
# 391                          Helena Haraštová      True
# 397                          Helena Haraštová      True
# 416                                Radka Píro      True
# 419                            Jitka Musilová      True
# 430                       Štěpánka Sekaninová      True
# 445                       Štěpánka Sekaninová      True
# 453                       Štěpánka Sekaninová      True
# 467                                Radka Píro      True
# 468                             Tom Velčovský      True
# 490                           Jana Sedláčková      True
# 543  Magda N. Garguláková;Štěpánka Sekaninová      True
# 552                       Štěpánka Sekaninová      True
# 568                          Bohdana Jarošová      True
# 578                          Bohdana Jarošová      True
#
#                            Book Name Scraping Original Category  \
# 10                                    A Day of Colours      NaN
# 34                               Alliance of the Brave      NaN
# 36                            Amazing Domestic Animals      NaN
# 41   An Atlas of Incredible Islands: Real stories o...      NaN
# 42                           An Explanatory Dictionary      NaN
# 80                  Atlas of Planet Earth for children      NaN
# 110         Characters in Literature and Their Stories      NaN
# 178                                           Frostina      NaN
# 186                            Get Ready for Christmas      NaN
# 187                            Get Ready for Halloween      NaN
# 190                                         Girl Power      NaN
# 209                            Hope It Turns Out Well!      NaN
# 316                            Magic World of Unicorns      NaN
# 319                               Mandalas Diamond Art      NaN
# 329                          Mum and Dad Have Split up      NaN
# 330                  Mum! Dad! I Want to be President!      NaN
# 355                                          On the Go      NaN
# 359              One Ball, Two Mice and What Came Next      NaN
# 367                            Parrots Are Great, but…      NaN
# 386                                  Rabbits Are Great      NaN
# 388                                   Rainbow Unicorns      NaN
# 391                  Rob Memory Doesn’t Want to Leave!      NaN
# 397       Scatterbrain the Bogey Doesn’t Want to Leave      NaN
# 416                    Shush! Do you hear the silence?      NaN
# 419                                    Smart Scribbles      NaN
# 430                                      Superstitions      NaN
# 445                    The Book of Disappearing Plants      NaN
# 453                            The Life of a Butterfly      NaN
# 467                                            The Sky      NaN
# 468                                       The Snipkins      NaN
# 490                                The Year in Colours      NaN
# 543                                   We’re Only Human      NaN
# 552                             What Goes On in a Town      NaN
# 568                         Who can do without a desk?      NaN
# 578                               Whose table is that?      NaN
#
#                                Scraped Series  \
# 10                             Learn and talk
# 34                                        NaN
# 36                                        NaN
# 41                                        NaN
# 42                                        NaN
# 80                       Atlases for Children
# 110  Remarkable Works of Art around the World
# 178                                       NaN
# 186                 Magic Tattoo Sticker Book
# 187                 Magic Tattoo Sticker Book
# 190             DeLuxe Activity Sticker Books
# 209                                       NaN
# 316             DeLuxe Activity Sticker Books
# 319                                       NaN
# 329                                       NaN
# 330                                       NaN
# 355           Reusable Activity Sticker Books
# 359                            Learn and talk
# 367             It’s Great to Have a Pet But…
# 386             It’s Great to Have a Pet But…
# 388           Reusable Activity Sticker Books
# 391           Keep Your Rascals Under Control
# 397           Keep Your Rascals Under Control
# 416                                       NaN
# 419                                       NaN
# 430                                       NaN
# 445                                       NaN
# 453                             Little Heroes
# 467                                       NaN
# 468                                       NaN
# 490                Nature’s Wonderful Colours
# 543                                       NaN
# 552                                       NaN
# 568             Learn about occupations with…
# 578             Learn about occupations with…
#
#                                         cleaned_titles
# 10                                    a day of colours
# 34                               alliance of the brave
# 36                            amazing domestic animals
# 41   an atlas of incredible islands: real stories o...
# 42                           an explanatory dictionary
# 80                  atlas of planet earth for children
# 110         characters in literature and their stories
# 178                                           frostina
# 186                            get ready for christmas
# 187                            get ready for halloween
# 190                                         girl power
# 209                             hope it turns out well
# 316                            magic world of unicorns
# 319                               mandalas diamond art
# 329                          mum and dad have split up
# 330                     mum dad i want to be president
# 355                                          on the go
# 359               one ball two mice and what came next
# 367                             parrots are great but…
# 386                                  rabbits are great
# 388                                   rainbow unicorns
# 391                   rob memory doesn't want to leave
# 397       scatterbrain the bogey doesn't want to leave
# 416                      shush do you hear the silence
# 419                                    smart scribbles
# 430                                      superstitions
# 445                    the book of disappearing plants
# 453                            the life of a butterfly
# 467                                            the sky
# 468                                       the snipkins
# 490                                the year in colours
# 543                                   we're only human
# 552                             what goes on in a town
# 568                          who can do without a desk
# 578                                whose table is that

# %%
# Filter rows where cleaned titles are in not_found_titles
filtered = albatros_missing[albatros_missing['cleaned_titles'].isin(not_found_titles)]

# Concatenate with prehled_vse instead of append
prehled_vse = pd.concat([prehled_vse, filtered], ignore_index=True)

# %% [markdown]
# ### Append scraped series and shuffle order of colums so that Scraped series are next to scraped stuff

# %%
prehled_vse['Scraped Series'] = prehled_vse['URL'].apply(lambda x: albatrosmedia[albatrosmedia['URL'] == x] ['Scraped Series'].values[0] if x in list(albatrosmedia['URL']) else None)
cols = list(prehled_vse.columns)
cols.insert(30, cols.pop(cols.index('Scraped Series'))) ## Shuffle order of columns 
prehled_vse = prehled_vse[cols]

# %% [markdown]
# #### Second round of unifying book names

# %%
fix_2 = {('Animal Adaptations: Extreme Conditions', 'Lida Larina'): 'Why Walruses Thrive On Ice and How Other Animals Survive the Heat or Darkness',
 ('Animal Adaptations: Unique Body Parts', 'Lida Larina'): 'Why the Anteater’s Tongue Is So Long and Other Ways Animals Are Equipped For Life',
 ('Bella and the Lost Ball', 'Mag Takac'):  'Betty and the Lost Ball',
 ('Bustling Cities of the World', 'Magdalena Konečná'): 'Colourful Cities', 
 ('Famous Finds and Finders: Searching for the Past', 'Adam Wolf'): 'Searching for the Past', 
 ('From Pyramids to Palaces: Architecture around the World', 'Marie Kraus'):'Forms of Architecture', # Grafika na obalu je trochu jiná, ale jinak stejná kniha 
 ('How Not to Kill Your Plant', 'Hannah Abbo'): 'I Have a House Plant Too', 
 ('Insectopia: The Wonderful World of Insects', 'Pavla Dvorská;Pavel Dvorský'): 'The Wonderful World of Insects', 
 ('Our Marvelous Memory', 'Dita Vopřadová'): 'Memory', 
 ('Parts of a Whole', 'Federico Bonifacini'): 'What Makes Things Things', 
 ('Planning Grandma’s Party: Measurements, Fractions, and Fun', 'Xiana Teimoy'): 'Grandma’s Amazing Celebration', 
 ('Our Camping Trip: Physics, Chemistry, and Fun', 'Xiana Teimoy'): 'Our Amazing Holiday',
 ('Say What? How We Communicate', 'Charlotte Molas'):'What? A Book About Communication and Understanding',
 ('Shapescapes', 'Lukáš Fibrich'):'What´s Happening in the Circle and in Other Shapes?',
 ('Snake Milker and Other Animal Jobs', 'Jakub Cenkl'): 'Occupations with Animals', 
 ('The Big Book of Jobs', 'Elena Pokaleva'): 'The Wonderful World of Jobs', # Diskutabilní, Obal je jiný, ale kniha pravděpodobně jinak stejná
 ('Tug Your Earlobe: A Picture Guide to Body Language', 'Adam Wolf'): 'Body Language and How to Read It', 
 ('Upside Down', 'Katarína Macurová'): 'Why Won’t You Flower?',
 ('What Goes Inside?', 'Federico Bonifacini'): 'What Fits Inside',
 ('What Plant Is This?', 'Carmen Saldaña'): 'What Is Growing Here?', 
 ('What should I wear now?', 'Alexandra Májová Hetmerová'):'Different Occasions', 
 ('What Should I Wear to Work?', 'Alexandra Májová Hetmerová'): 'Occupations',
 ('What Things Come From Nature?', 'Anastasiia Moshina'): 'What Does Nature Give Us?',
 ('What To Do If You Meet a Bear? A Nature Survival Guide', 'Adam Wolf'):'Animal Encounters',
 ('Where To? A Trip Around the Neighborhood', 'Tomáš Kopecký'): 'I Will Smartly Find My Way', 
 ('Words About Where: Let’s Learn Prepositions', 'Marie Urbankova'): 'In, On or Above? Let´s Learn Prepositions', 
 ('World Record Animals', 'Tomáš Pernický'): 'Records of the Animal World',
 ('Jak se stát akčním hrdinou', 'Martin Šojdr; Tomáš Pernický'): 'I Want to Be an Action Hero', 
 ('Kudy teče řeka', 'Mária Nerádová'): 'Mária Nerádová',
 ('Jak se stát hvězdou', 'Kateřina Hikadová; Ondřej Dolejší; Tomáš Pernický; Martina Lišková'): 'I Want to Be a Star', 
 ('Jak se stát mistrem vypravěčem', 'Kateřina Hikadová; Ondřej Dolejší; Tomáš Pernický; Tomáš Kučerovský'): 'I Want to Be a Storyteller',
 ('Kapka Kája', 'Edit Sliacka'): 'Rosie the Raindrop', 
 ('Čáp Čeněk', 'Edit Sliacka'):'Samie the Stork',
 ('Mraveniště', 'Tomáš Tůma'): 'Anthill (How Animals Live)', 
 ('Vyber si svou rostlinku... a nauč se o ni starat', 'Aneta Žabková'): 'Choose a Plant… and Learn to Care for It', 
 ('Vyber si svého mazlíčka... a nauč se o něj starat', 'Aneta Žabková'): 'Choose a Pet… and Learn to Care for It'}

fix_3 = {('Sevenspot’s Adventures for Little Readers', 'Vojtěch Kubašta'): 'The Adventures of Sevenspot for Little Readers',
         ('Animals', 'Marie Urbánková'): 'Animals (Got It)',
         ('Colours', 'Marie Urbánková'): 'Colours (Got It)'}

for key, value in fix_2.items():
    title = key[0]
    illustrator = key[1]
    prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
    prehled_vse.loc[(prehled_vse['Book Name AlbatrosBook Original'] == title) & (prehled_vse['Illustrators Scraped AlbatrosBook'] == illustrator), 'Název knihy'] = value

for key, value in fix_3.items():
    title = key[0]
    illustrator = key[1]
    prehled_vse.loc[(prehled_vse['Book Name'] == title) & (prehled_vse['Illustrators Scraped'] == illustrator), 'Název knihy'] = value
    print(prehled_vse.loc[(prehled_vse['Illustrators Scraped'] == illustrator), 'Název knihy'])

prehled_vse['cleaned_titles'] =  prehled_vse['Název knihy'].apply(clean_title_fun)

# Separate rows with missing 'Název knihy'
df_missing = prehled_vse[prehled_vse['cleaned_titles'].isnull()]
# Out:
# 29                         A House Full of Little Wheels
# 31                        A Little House Full of Friends
# 47                      Alice’s Adventures in Wonderland
# 86                               Animals and the Robbers
# 87                            Animals and the Sports Day
# 96                                     Animals on Safari
# 156                                    Brave Tin Soldier
# 177                                           Cinderella
# 221                    Dozen Stories for the Little Ones
# 255                               Fisherman and his Wife
# 279                                          Golden Fish
# 290                   Hansel and Gretel (Vintage Pop-Up)
# 291      Hansel and Gretel (Vojtech Kubasta Fairy Tales)
# 403                               Jack and the Beanstalk
# 425                                Let the Table Be Set!
# 466                               Little Red Riding Hood
# 469              Little Red Riding Hood (Vintage Pop-Up)
# 546                                     Once Upon a Time
# 598                                    Puss in the Boots
# 611                                      Robinson Crusoe
# 633       The Adventures of Sevenspot for Little Readers
# 648        Sleeping Beauty (Vojtech Kubasta Fairy Tales)
# 654    Snow White and the Seven Dwarfs (Vintage Pop-Ups)
# 655    Snow White and the Seven Dwarfs (Vojtech Kubas...
# 682      The Adventures of Sevenspot the Ladybird Beetle
# 683                           The Animals and their Band
# 690                             The Cricket and the Ants
# 702                       The Little Car and the Animals
# 709                       The Little Tractor and Animals
# 710                          The Little Train is Coming!
# 739                                        The Tinderbox
# 745                    The Wolf & the Seven Little Goats
# 768                                          Three Bears
# 769                                   Three Golden Hairs
# 770                                    Three Little Pigs
# 776                                     Tip & Top at Sea
# 777                                 Tip & Top At the Zoo
# 778                                Tip & Top Build a Car
# 779                            Tip & Top in an Aeroplane
# 780                                Tip & Top On the Farm
# 781                                Tip & Top on the Moon
# 891                                        Wishing Table
# Name: Název knihy, dtype: object
# 85                          Animals (Got It)
# 188                         Colours (Got It)
# 361             I Am in Love With My Bicycle
# 362    I Am in Love With My Skis & Snowboard
# 398                        In, On, or Above?
# 406                                     Jobs
# 523                         Numbers (Got It)
# 638                          Shapes (Got It)
# 676             Teeth: You Only Get Two Sets
# 816                                 Vehicles
# Name: Název knihy, dtype: object
# 85                          Animals (Got It)
# 188                         Colours (Got It)
# 361             I Am in Love With My Bicycle
# 362    I Am in Love With My Skis & Snowboard
# 398                        In, On, or Above?
# 406                                     Jobs
# 523                         Numbers (Got It)
# 638                          Shapes (Got It)
# 676             Teeth: You Only Get Two Sets
# 816                                 Vehicles
# Name: Název knihy, dtype: object
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/491281583.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prehled_vse.loc[(prehled_vse['Book Name AlbatrosBooks'] == title) & (prehled_vse['Illustrator NK'] == illustrator)]['Název knihy'] = value

# %%
# 2. Group the non-missing ones
def combine_values(series):
    return '$ '.join(sorted(set(str(v) for v in series.dropna() if str(v).strip())))

df_grouped = prehled_vse[prehled_vse['cleaned_titles'].notna()].groupby('cleaned_titles').agg(combine_values).reset_index()


# 3. Combine them back
prehled_vse = pd.concat([df_grouped, df_missing], ignore_index=True)

# Replace empty strings and strings with only whitespace with None
prehled_vse = prehled_vse.replace(r'^\s*$', None, regex=True)
# Out:
# /var/folders/sq/pxhs33t53bz1x33q9fhn04w00000gn/T/ipykernel_26116/295777133.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   prehled_vse = prehled_vse.replace(r'^\s*$', None, regex=True)

# %%
if pd.notnull(prehled_vse[prehled_vse['Book Name NK Original'] == 'Versatile vertebrates'].Scraping.values[0]): print('Not NaN')
else: print('NaN')
# Out:
# Not NaN

# %% [markdown]
# #### Change ones to True

# %%
def is_valid(value):
    if pd.isnull(value):  # catches None and NaN
        return False
    if isinstance(value, str) and value.strip() != '':
        return True
    return False

def age_size(row):
    if pd.notnull(row.get('je věk a rozměr'))  : return True
    if is_valid(row.get('Age')) and is_valid(row.get('Book Parametes')):  
        return True
    return None

def languages(row):
    print(row)
    if pd.notnull(row.get('jsou jazyky')) : return True
    if is_valid(row.get('Sold To')) : return True #and row['Sold To'] != 'Not found'
    if is_valid(row.get('Languages')) : return True 
    return None

def is_all(row):
    if all(pd.notnull(row[['je PDF', 'je věk a rozměr', 'jsou jazyky']])) : return True


prehled_vse.Scraping = prehled_vse.Scraping.apply(lambda x: True if pd.notnull(x)  else None)
prehled_vse.Albatros = prehled_vse.Albatros.apply(lambda x: True if pd.notnull(x)  else None) 
prehled_vse['B4U NK'] = prehled_vse['B4U NK'].apply(lambda x: True if pd.notnull(x)  else None)
prehled_vse['Sold Licence'] = prehled_vse['Sold Licence'].apply(lambda x: True if pd.notnull(x)  else None) 
prehled_vse['je PDF'] = prehled_vse['je PDF'].apply(lambda x: True if pd.notnull(x) else None) 
prehled_vse['je vše'] = prehled_vse['je vše'].apply(lambda x: True if pd.notnull(x) else None) 
prehled_vse['Scraping AlbatrosBook'] = prehled_vse['Scraping AlbatrosBook'].apply(lambda x: True if pd.notnull(x) else None)

# %% [markdown]
# ### Unify - add True where it belongs

# %%
prehled_vse['je věk a rozměr'] = prehled_vse[['Age', 'Book Parametes', 'je věk a rozměr']].apply(lambda x: age_size(x), axis = 1)
prehled_vse['jsou jazyky'] = prehled_vse[['jsou jazyky', 'Sold To', 'Languages']].apply(lambda x: languages(x), axis = 1)
prehled_vse['je vše'] = prehled_vse[['je PDF', 'je věk a rozměr', 'jsou jazyky']].apply(lambda x: is_all(x), axis = 1)
prehled_vse['Unnamed: 1'] = prehled_vse[['Unnamed: 0', 'Unnamed: 1']].apply(lambda x: 'alternativní názvy' if '$' in str(x['Unnamed: 0']) else x['Unnamed: 1'], axis=1)
prehled_vse['Název knihy'] = prehled_vse['Název knihy'].apply(lambda x: x.partition('$')[0] if '$' in str(x) else x)
prehled_vse['Book Name'] = prehled_vse['Book Name'].apply(lambda x: x.partition('$')[0] if '$' in str(x) else x)
# Out:
# jsou jazyky                        1.0
# Sold To                           None
# Languages      ['Hungarian', 'Polish']
# Name: 0, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 1, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 2, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 3, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Slovene', 'Hungarian', 'Polish', 'Bulgarian'...
# Name: 4, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 5, dtype: object
# jsou jazyky                                               1.0
# Sold To                                                  None
# Languages      ['Slovene', 'Hungarian', 'Polish', 'Romanian']
# Name: 6, dtype: object
# jsou jazyky                         1.0
# Sold To                            None
# Languages      ['Slovene', 'Hungarian']
# Name: 7, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 8, dtype: object
# jsou jazyky                                    1.0
# Sold To                                       None
# Languages      ['Hungarian', 'Estonian', 'Polish']
# Name: 9, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 10, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Polish', 'Estonian']
# Name: 11, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Estonian', 'Polish']
# Name: 12, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, Spanish, Italian, Serbian, English, S...
# Languages      ['Italian', 'Catalan; Spanish', 'Serbian', 'En...
# Name: 13, dtype: object
# jsou jazyky                                           1.0
# Sold To              Catalan, Simplified Chinese, Spanish
# Languages      ['Simplified Chinese', 'Catalan; Spanish']
# Name: 14, dtype: object
# jsou jazyky                                                  1.0
# Sold To                              Russian, Simplified Chinese
# Languages      ['Simplified Chinese', 'English', 'Russian', '...
# Name: 15, dtype: object
# jsou jazyky                                                  1.0
# Sold To        German, Simplified Chinese, Ukrainian, Vietnamese
# Languages      ['Simplified Chinese', 'English', 'Polish', 'R...
# Name: 16, dtype: object
# jsou jazyky                                                  1.0
# Sold To                Simplified Chinese, Ukrainian, Vietnamese
# Languages      ['Simplified Chinese', 'English', 'Russian', '...
# Name: 17, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic for Israel, Catalan, Complex Chinese, E...
# Languages      ['Hebrew', 'Arabic', 'Simplified Chinese', 'Ko...
# Name: 18, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Polish, Russian, Slovene,\nPortuguese excl. Br...
# Languages      ['Polish', 'Slovene', 'Simplified Chinese', 'C...
# Name: 19, dtype: object
# jsou jazyky                                     1.0
# Sold To                                        None
# Languages      ['Portuguese', 'Simplified Chinese']
# Name: 20, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, Dutch, French, German, Russian, Spani...
# Languages      ['Simplified Chinese', 'Polish', 'German', 'Ge...
# Name: 21, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Simplified Chinese']
# Name: 22, dtype: object
# jsou jazyky                                                1.0
# Sold To                                    Estonian, Bulgarian
# Languages      ['Bulgarian', 'Estonian', 'Simplified Chinese']
# Name: 23, dtype: object
# jsou jazyky                                  1.0
# Sold To                Bulgarian, Greek, Spanish
# Languages      ['Greek', 'Spanish', 'Bulgarian']
# Name: 24, dtype: object
# jsou jazyky                                  1.0
# Sold To                Bulgarian, Greek, Spanish
# Languages      ['Greek', 'Spanish', 'Bulgarian']
# Name: 25, dtype: object
# jsou jazyky              1.0
# Sold To                 None
# Languages      ['Bulgarian']
# Name: 26, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, Greek, Italian, Lithuanian, Slovene...
# Languages      ['Slovene', 'Bulgarian', 'Lithuanian', 'Italia...
# Name: 27, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 28, dtype: object
# jsou jazyky      None
# Sold To        Russia
# Languages        None
# Name: 29, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 30, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 31, dtype: object
# jsou jazyky                           1.0
# Sold To         Italian, Romanian, French
# Languages                      ['French']
# Name: 32, dtype: object
# jsou jazyky                          1.0
# Sold To        Italian, Romanian, French
# Languages                     ['French']
# Name: 33, dtype: object
# jsou jazyky                                 1.0
# Sold To                French, Latvian, Italian
# Languages      ['Latvian', 'Italian', 'French']
# Name: 34, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Simplified Chinese', 'Italian', 'Slovene', '...
# Name: 35, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Simplified Chinese', 'Estonian', 'Italian', ...
# Name: 36, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Greek', 'Italian', 'Simplified Chinese', 'Vi...
# Name: 37, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 38, dtype: object
# jsou jazyky                                1.0
# Sold To                     Simplified Chinese
# Languages      ['Simplified Chinese', 'Uzbek']
# Name: 39, dtype: object
# jsou jazyky                                1.0
# Sold To                     Simplified Chinese
# Languages      ['Simplified Chinese', 'Uzbek']
# Name: 40, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Simplified Chinese, Estonian, Greek, Italian, ...
# Languages      ['Estonian', 'Simplified Chinese', 'Spanish', ...
# Name: 41, dtype: object
# jsou jazyky                           1.0
# Sold To              Estonian, Vietnamese
# Languages      ['Estonian', 'Vietnamese']
# Name: 42, dtype: object
# jsou jazyky                      1.0
# Sold To              Greek, Romanian
# Languages      ['Greek', 'Romanian']
# Name: 43, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 44, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Slovene']
# Name: 45, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 46, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  Estonian, French for Europe,...
# Languages      ['Estonian', 'Italian', 'Slovene', 'French', '...
# Name: 47, dtype: object
# jsou jazyky                                             1.0
# Sold To                Simplified Chinese, Vietnamese, Thai
# Languages      ['Simplified Chinese', 'Vietnamese', 'Thai']
# Name: 48, dtype: object
# jsou jazyky                                                  1.0
# Sold To        French, Italian,  Simplified Chinese,  Vietnamese
# Languages      ['Vietnamese', 'Simplified Chinese', 'French',...
# Name: 49, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, Catalan, English, Italian, Slovak, ...
# Languages      ['Catalan; Spanish', 'Italian', 'Slovak', 'Bul...
# Name: 50, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Spanish', 'Catalan']
# Name: 51, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 52, dtype: object
# jsou jazyky                       1.0
# Sold To            Simplified Chinese
# Languages      ['Simplified Chinese']
# Name: 53, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Italian, French, Simplified Chinese, Thai, German
# Languages      ['Italian', 'French', 'Simplified Chinese', 'T...
# Name: 54, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Italian, French, Simplified Chinese, Thai, German
# Languages      ['Italian', 'French', 'Simplified Chinese', 'T...
# Name: 55, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 56, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, French, Italian, Russian, ...
# Languages      ['Bulgarian', 'English', 'Spanish', 'Italian',...
# Name: 57, dtype: object
# jsou jazyky                                                  1.0
# Sold To                     Simplified Chinese, Spanish, Turkish
# Languages      ['Spanish', 'Turkish', 'Simplified Chinese', '...
# Name: 58, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, French, Simplified Chinese...
# Languages      ['Bulgarian', 'French', 'English', 'Turkish', ...
# Name: 59, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 60, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Simplified Chinese']
# Name: 61, dtype: object
# jsou jazyky                                       1.0
# Sold To                Croatian, Portuguese, Romanian
# Languages      ['Portuguese', 'Romanian', 'Croatian']
# Name: 62, dtype: object
# jsou jazyky                      1.0
# Sold To              French, Spanish
# Languages      ['French', 'Spanish']
# Name: 63, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Slovene']
# Name: 64, dtype: object
# jsou jazyky                          1.0
# Sold To                             None
# Languages      ['Lithuanian', 'Latvian']
# Name: 65, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 66, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 67, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, Georgian, German, Greek, Korean, Mong...
# Languages      ['English', 'Dutch', 'Greek', 'Italian', 'Simp...
# Name: 68, dtype: object
# jsou jazyky                                                  1.0
# Sold To                        Dutch, French, Simplified Chinese
# Languages      ['French', 'Dutch', 'Simplified Chinese', 'Eng...
# Name: 69, dtype: object
# jsou jazyky                                                  1.0
# Sold To                        Dutch, French, Simplified Chinese
# Languages      ['French', 'Dutch', 'Simplified Chinese', 'Eng...
# Name: 70, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  English for Hong Kong  and M...
# Languages      ['Italian', 'Norwegian', 'Swedish', 'Finnish',...
# Name: 71, dtype: object
# jsou jazyky                                  1.0
# Sold To                                  English
# Languages      ['English', 'Simplified Chinese']
# Name: 72, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 73, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  Hungarian, Lithuanian,  Simp...
# Languages      ['Ukrainian', 'Simplified Chinese', 'Complex C...
# Name: 74, dtype: object
# jsou jazyky                                                  1.0
# Sold To            French, Italian,  Simplified Chinese, Spanish
# Languages      ['Simplified Chinese', 'Russian', 'French', 'I...
# Name: 75, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  English for Hong Kong  and M...
# Languages      ['Italian', 'Norwegian', 'Swedish', 'Finnish',...
# Name: 76, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  Simplified Chinese,  Spanish...
# Languages      ['Ukrainian', 'Simplified Chinese', 'Complex C...
# Name: 77, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 78, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Croatian, Dutch, English, French, Greek, Itali...
# Languages      ['English; Simplified Chinese', 'Portuguese', ...
# Name: 79, dtype: object
# jsou jazyky              1.0
# Sold To            Hungarian
# Languages      ['Hungarian']
# Name: 80, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 81, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 82, dtype: object
# jsou jazyky                                  1.0
# Sold To                Spanish, English, Russian
# Languages      ['English', 'Spanish', 'Russian']
# Name: 83, dtype: object
# jsou jazyky                                                  1.0
# Sold To             Dutch, Serbian, Spanish, Turkish, Vietnamese
# Languages      ['Simplified Chinese', 'Slovene', 'Italian', '...
# Name: 84, dtype: object
# jsou jazyky                       1.0
# Sold To                       Russian
# Languages      ['Spanish', 'Russian']
# Name: 85, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 86, dtype: object
# jsou jazyky                                     1.0
# Sold To                                        None
# Languages      ['Simplified Chinese', 'Portuguese']
# Name: 87, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Greek', 'Italian', 'Simplified Chinese', 'Vi...
# Name: 88, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 89, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 90, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 91, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 92, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 93, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 94, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 95, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 96, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 97, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 98, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 99, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 100, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, Bulgarian, Dutch, English, French, Ger...
# Languages      ['Finnish', 'Slovene', 'Simplified Chinese', '...
# Name: 101, dtype: object
# jsou jazyky                                                  1.0
# Sold To             Complex Chinese, English, Simplified Chinese
# Languages      ['Slovene', 'Italian', 'Simplified Chinese', '...
# Name: 102, dtype: object
# jsou jazyky                                                  1.0
# Sold To         Croatian, Korean, Simplified Chinese, Vietnamese
# Languages      ['Korean', 'Vietnamese', 'Croatian', 'Simplifi...
# Name: 103, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                    Ukrainian, Vietnamese
# Languages      ['Estonian', 'Spanish', 'Russian', 'Simplified...
# Name: 104, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 105, dtype: object
# jsou jazyky             1.0
# Sold To            Estonian
# Languages      ['Estonian']
# Name: 106, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Simplified Chinese, Bulgarian, Spanish, Estoni...
# Languages      ['Simplified Chinese', 'Spanish', 'Bulgarian',...
# Name: 107, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, Galician, German, Hungarian, ...
# Languages      ['German', 'Portuguese', 'Galician', 'French',...
# Name: 108, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 109, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 110, dtype: object
# jsou jazyky                                           1.0
# Sold To                       Simplified Chinese, Spanish
# Languages      ['Spanish', 'Simplified Chinese', 'Uzbek']
# Name: 111, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, Estonian, French, Galician, German, G...
# Languages      ['Simplified Chinese', 'Spanish', 'Vietnamese'...
# Name: 112, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, Italian, Mongolian, Portugues...
# Languages      ['Mongolian', 'Italian', 'French', 'Portuguese...
# Name: 113, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, Greek, Italian, Mongolian, Po...
# Languages      ['Italian', 'Portuguese', 'Greek', 'English', ...
# Name: 114, dtype: object
# jsou jazyky                                   1.0
# Sold To                English, French, Mongolian
# Languages      ['French', 'Mongolian', 'English']
# Name: 115, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Azerbaijani, English, Italian, Russian, Simpli...
# Languages      ['Russian', 'English', 'Spanish', 'Italian', '...
# Name: 116, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Azerbaijani, English, Estonian, Italian, Kazak...
# Languages      ['English', 'Russian', 'Spanish', 'Italian', '...
# Name: 117, dtype: object
# jsou jazyky                                                  1.0
# Sold To                           Portuguese for Europe, Spanish
# Languages      ['Greek', 'Italian', 'Portuguese', 'Bulgarian'...
# Name: 118, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, Hungarian, Japanese, Korean, Russian ...
# Languages      ['Spanish', 'Simplified Chinese', 'Estonian', ...
# Name: 119, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                  Spanish
# Languages      ['Dutch', 'Greek', 'Italian', 'Spanish', 'Simp...
# Name: 120, dtype: object
# jsou jazyky                       1.0
# Sold To              English, Spanish
# Languages      ['English', 'Spanish']
# Name: 121, dtype: object
# jsou jazyky                                                  1.0
# Sold To        French, German, Mongolian, Simplified Chinese,...
# Languages      ['Spanish', 'Spanish', 'Slovene', 'Simplified ...
# Name: 122, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese, Greek, Mongolian, Polish, Por...
# Languages      ['Spanish', 'Mongolian', 'Italian', 'Slovene',...
# Name: 123, dtype: object
# jsou jazyky                                                  1.0
# Sold To                              English, Mongolian, Spanish
# Languages      ['English', 'Greek', 'Italian', 'Slovene', 'Po...
# Name: 124, dtype: object
# jsou jazyky                                                  1.0
# Sold To             Bulgarian, English, German, Russian, Spanish
# Languages      ['English', 'Spanish', 'Russian', 'Bulgarian',...
# Name: 125, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                Italian, Slovene, Spanish
# Languages      ['Simplified Chinese', 'Spanish', 'Italian', '...
# Name: 126, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 127, dtype: object
# jsou jazyky                                   1.0
# Sold To                Italian, Portuguese, Greek
# Languages      ['Italian', 'Greek', 'Portuguese']
# Name: 128, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 129, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 130, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                      English, Vietnamese
# Languages      ['Vietnamese', 'English (non-exclusive)', 'Bul...
# Name: 131, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 132, dtype: object
# jsou jazyky                                       1.0
# Sold To                           English, Vietnamese
# Languages      ['Vietnamese', 'English', 'Bulgarian']
# Name: 133, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 134, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 135, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, Bulgarian, Danish, Dutch,English, Fren...
# Languages      ['Slovene', 'Lithuanian', 'Estonian', 'Simplif...
# Name: 136, dtype: object
# jsou jazyky                                                  1.0
# Sold To            Complex Chinese, English, Simplified Chinese,
# Languages      ['Slovene', 'Italian', 'Simplified Chinese', '...
# Name: 137, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Spanish']
# Name: 138, dtype: object
# jsou jazyky                    1.0
# Sold To        Serbian, Vietnamese
# Languages           ['Vietnamese']
# Name: 139, dtype: object
# jsou jazyky                                        1.0
# Sold To                       Complex Chinese, Italian
# Languages      ['Italian', 'Complex Chinese', 'Uzbek']
# Name: 140, dtype: object
# jsou jazyky                                                  1.0
# Sold To                     Bulgarian, English, Spanish, Turkish
# Languages      ['English', 'Spanish', 'Bulgarian', 'English (...
# Name: 141, dtype: object
# jsou jazyky                                            1.0
# Sold To                Korean, Russian, Simplified Chinese
# Languages      ['Simplified Chinese', 'Korean', 'Russian']
# Name: 142, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 143, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, Georgian, Slovene, Ukrainian,...
# Languages      ['Vietnamese', 'French', 'English', 'Slovene',...
# Name: 144, dtype: object
# jsou jazyky            1.0
# Sold To            English
# Languages      ['English']
# Name: 145, dtype: object
# jsou jazyky              1.0
# Sold To            Hungarian
# Languages      ['Hungarian']
# Name: 146, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese, English, German, Italian, Kor...
# Languages      ['Czech', 'Korean', 'German', 'Simplified Chin...
# Name: 147, dtype: object
# jsou jazyky           1.0
# Sold To            French
# Languages      ['French']
# Name: 148, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 149, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Latvian']
# Name: 150, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 151, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                               Vietnamese
# Languages      ['Russian', 'Simplified Chinese', 'Ukrainian',...
# Name: 152, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['French']
# Name: 153, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 154, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, Polish, Portuguese, Simpli...
# Languages      ['Ukrainian', 'Simplified Chinese', 'Turkish',...
# Name: 155, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, Bulgarian, Complex Chinese, English, G...
# Languages      ['Greek', 'Serbian', 'Spanish', 'English', 'Bu...
# Name: 156, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 157, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Simplified Chinese, Finnish,\nGreek, Portugues...
# Languages      ['Finnish', 'Greek', 'Portuguese', 'Simplified...
# Name: 158, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Simplified Chinese, Greek,\nPortuguese for Eur...
# Languages      ['Greek', 'Portuguese', 'Simplified Chinese', ...
# Name: 159, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 160, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, Estonian, German, Italian, Slovak, ...
# Languages      ['Slovak', 'Estonian', 'Italian', 'Spanish', '...
# Name: 161, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, English, Greek, Italian, Romanian, Se...
# Languages      ['Greek', 'Catalan; Spanish', 'Italian', 'Serb...
# Name: 162, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, Greek, Italian, Polish, Vi...
# Languages      ['Greek', 'Slovene', 'Russian', 'French', 'Kor...
# Name: 163, dtype: object
# jsou jazyky                                                 1.0
# Sold To                  Bulgarian, Hungarian, Estonian, Polish
# Languages      ['Hungarian', 'Bulgarian', 'Estonian', 'Polish']
# Name: 164, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Russian']
# Name: 165, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Ukrainian', 'Simplified Chinese', 'Complex C...
# Name: 166, dtype: object
# jsou jazyky                                                  1.0
# Sold To        German, Japanese, Korean, Russian, Simplified ...
# Languages      ['English', 'German', 'Simplified Chinese', 'R...
# Name: 167, dtype: object
# jsou jazyky                       1.0
# Sold To            Simplified Chinese
# Languages      ['Simplified Chinese']
# Name: 168, dtype: object
# jsou jazyky                                                  1.0
# Sold To           Greek, Italian, Slovene, Ukrainian, Vietnamese
# Languages      ['Greek', 'Slovene', 'Italian', 'Vietnamese', ...
# Name: 169, dtype: object
# jsou jazyky              1.0
# Sold To            Norwegian
# Languages      ['Norwegian']
# Name: 170, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, German, Italian, Polish, Russ...
# Languages      ['Simplified Chinese', 'Spanish', 'French', 'E...
# Name: 171, dtype: object
# jsou jazyky                               1.0
# Sold To                Dutch, German, Spanish
# Languages      ['German', 'Dutch', 'Spanish']
# Name: 172, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Croatian, English, French, Greek, Italian, Pol...
# Languages      ['Polish', 'English; Simplified Chinese', 'Por...
# Name: 173, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, English,  Hebrew, Korean, Spanish, Ukr...
# Languages      ['Simplified Chinese', 'Complex Chinese', 'Ita...
# Name: 174, dtype: object
# jsou jazyky              1.0
# Sold To                 None
# Languages      ['Icelandic']
# Name: 175, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 176, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, Complex Chinese, Danish, Dutch, Engli...
# Languages      ['Simplified Chinese', 'Spanish', 'English', '...
# Name: 177, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese, English, Estonian, Italian, R...
# Languages      ['Complex Chinese', 'Spanish', 'English', 'Vie...
# Name: 178, dtype: object
# jsou jazyky                          1.0
# Sold To              Russian, Vietnamese
# Languages      ['Vietnamese', 'Russian']
# Name: 179, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 180, dtype: object
# jsou jazyky                                            1.0
# Sold To                           French, Swedish, Spanish
# Languages      ['French', 'Swedish', 'Spanish', 'Italian']
# Name: 181, dtype: object
# jsou jazyky                      1.0
# Sold To              French, Spanish
# Languages      ['French', 'Spanish']
# Name: 182, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 183, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Italian']
# Name: 184, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, French, Galician, German, ...
# Languages      ['Galician', 'German', 'French', 'Spanish', 'S...
# Name: 185, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['English']
# Name: 186, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 187, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 188, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 189, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Simplified Chinese, Estonian, Polish, Complex ...
# Languages      ['Estonian', 'Polish', 'Simplified Chinese', '...
# Name: 190, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 191, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, English, French, German, Italian, Rom...
# Languages      ['Slovene', 'Romanian', 'French', 'German', 'C...
# Name: 192, dtype: object
# jsou jazyky                                    1.0
# Sold To                English, French, Vietnamese
# Languages      ['French', 'English', 'Vietnamese']
# Name: 193, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Simplified Chinese']
# Name: 194, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  Italian, Korean, Simplified ...
# Languages      ['Italian', 'Complex Chinese', 'Simplified Chi...
# Name: 195, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese,  English, French, Italian,  K...
# Languages      ['English', 'Spanish', 'Portuguese', 'French',...
# Name: 196, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, Complex Chinese, English, Polish, S...
# Languages      ['English', 'Hungarian', 'English', 'Finnish',...
# Name: 197, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 198, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                  Italian
# Languages      ['French', 'Simplified Chinese', 'Russian', 'E...
# Name: 199, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, Polish, Portuguese, Simpli...
# Languages      ['Ukrainian', 'Complex Chinese; Simplified Chi...
# Name: 200, dtype: object
# jsou jazyky                                        1.0
# Sold To         Russian, Simplified Chinese,\nJapanese
# Languages            ['Simplified Chinese', 'Russian']
# Name: 201, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Croatian, French, German, Korean, Simplified C...
# Languages      ['Simplified Chinese', 'Polish', 'Korean', 'Ru...
# Name: 202, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 203, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 204, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 205, dtype: object
# jsou jazyky               1.0
# Sold To                  None
# Languages      ['Portuguese']
# Name: 206, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                       Simplified Chinese
# Languages      ['English; Simplified Chinese', 'Catalan; Span...
# Name: 207, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, Italian, Mongolian, Polish...
# Languages      ['Portuguese', 'Italian', 'Danish', 'Spanish',...
# Name: 208, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, English, Italian, Russian, Spanish, T...
# Languages      ['English', 'Italian', 'Russian', 'Turkish', '...
# Name: 209, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, Italian, Korean, Polish, Russ...
# Languages      ['Simplified Chinese', 'Korean', 'Italian', 'V...
# Name: 210, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bosnian, Bulgarian, Complex Chinese, English, ...
# Languages      ['Simplified Chinese', 'Vietnamese', 'Korean',...
# Name: 211, dtype: object
# jsou jazyky                                            1.0
# Sold To                           English, French, Italian
# Languages      ['Italian', 'English', 'French', 'Turkish']
# Name: 212, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese, English, Latvian, Romanian, R...
# Languages      ['English', 'Simplified Chinese', 'Romanian', ...
# Name: 213, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['German']
# Name: 214, dtype: object
# jsou jazyky                                              1.0
# Sold To                                                 None
# Languages      ['Hungarian', 'Polish', 'Simplified Chinese']
# Name: 215, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                               Vietnamese
# Languages      ['Vietnamese', 'English (non-exclusive)', 'Gre...
# Name: 216, dtype: object
# jsou jazyky              1.0
# Sold To                 None
# Languages      ['Icelandic']
# Name: 217, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 218, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Persian']
# Name: 219, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Spanish', 'Persian']
# Name: 220, dtype: object
# jsou jazyky                                               1.0
# Sold To                         Bulgarian, Simplified Chinese
# Languages      ['Russian', 'Simplified Chinese', 'Bulgarian']
# Name: 221, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, Complex Chinese, Simplified Chinese...
# Languages      ['Bulgarian', 'Simplified Chinese', 'Complex C...
# Name: 222, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 223, dtype: object
# jsou jazyky                                     1.0
# Sold To              Simplified Chinese, Vietnamese
# Languages      ['Simplified Chinese', 'Vietnamese']
# Name: 224, dtype: object
# jsou jazyky                                    1.0
# Sold To                                       None
# Languages      ['Simplified Chinese', 'Mongolian']
# Name: 225, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 226, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Polish', 'English', 'English', 'Slovene', 'C...
# Name: 227, dtype: object
# jsou jazyky                       1.0
# Sold To            Simplified Chinese
# Languages      ['Simplified Chinese']
# Name: 228, dtype: object
# jsou jazyky       None
# Sold To        Slovene
# Languages         None
# Name: 229, dtype: object
# jsou jazyky           1.0
# Sold To              None
# Languages      ['Polish']
# Name: 230, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, German, Italian, Portugues...
# Languages      ['English', 'Portuguese', 'Italian', 'German',...
# Name: 231, dtype: object
# jsou jazyky                                                  1.0
# Sold To                    Dutch, French, Russian, Spanish, Thai
# Languages      ['Thai', 'French', 'Spanish', 'Russian', 'Dutch']
# Name: 232, dtype: object
# jsou jazyky                                                  1.0
# Sold To                      English, French, Hungarian, Italian
# Languages      ['Simplified Chinese', 'Greek', 'Spanish', 'Sl...
# Name: 233, dtype: object
# jsou jazyky                                            1.0
# Sold To                English, French, Simplified Chinese
# Languages      ['Simplified Chinese', 'French', 'English']
# Name: 234, dtype: object
# jsou jazyky                                                  1.0
# Sold To                              Simplified Chinese, Spanish
# Languages      ['Simplified Chinese', 'Spanish', 'Spanish', '...
# Name: 235, dtype: object
# jsou jazyky                                                  1.0
# Sold To                              Simplified Chinese, Spanish
# Languages      ['Simplified Chinese', 'Spanish', 'Spanish', '...
# Name: 236, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Simplified Chinese']
# Name: 237, dtype: object
# jsou jazyky                       1.0
# Sold To                          None
# Languages      ['Simplified Chinese']
# Name: 238, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Spanish']
# Name: 239, dtype: object
# jsou jazyky                                           1.0
# Sold To                Russian, Simplified Chinese, Uzbek
# Languages      ['Simplified Chinese', 'Uzbek', 'Russian']
# Name: 240, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 241, dtype: object
# jsou jazyky                                              1.0
# Sold To                           English, Galician, Spanish
# Languages      ['Spanish', 'English', 'Galician', 'Turkish']
# Name: 242, dtype: object
# jsou jazyky                                              1.0
# Sold To                  Bulgarian, German, Italian, Serbian
# Languages      ['Italian', 'Serbian', 'German', 'Bulgarian']
# Name: 243, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Lithuanian', 'Estonian', 'Bulgarian', 'Engli...
# Name: 244, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, Bulgarian, English, German, Greek, Ita...
# Languages      ['Lithuanian', 'Russian', 'French', 'Polish', ...
# Name: 245, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, Bulgarian, German, Greek, Italian, Lit...
# Languages      ['Simplified Chinese', 'Polish', 'German', 'Ro...
# Name: 246, dtype: object
# jsou jazyky                                         1.0
# Sold To                                       Bulgarian
# Languages      ['Bulgarian', 'English (non-exclusive)']
# Name: 247, dtype: object
# jsou jazyky                        1.0
# Sold To                           None
# Languages      ['Hungarian', 'Polish']
# Name: 248, dtype: object
# jsou jazyky                      1.0
# Sold To                         None
# Languages      ['English', 'French']
# Name: 249, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 250, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 251, dtype: object
# jsou jazyky                                           1.0
# Sold To                  English, German, Korean, Spanish
# Languages      ['Spanish', 'Korean', 'English', 'German']
# Name: 252, dtype: object
# jsou jazyky                                                  1.0
# Sold To                        English, French, Indonesian, Thai
# Languages      ['Thai', 'French', 'English', 'Indonesian', 'U...
# Name: 253, dtype: object
# jsou jazyky      None
# Sold To        Russia
# Languages        None
# Name: 254, dtype: object
# jsou jazyky               1.0
# Sold To            Lithuanian
# Languages      ['Lithuanian']
# Name: 255, dtype: object
# jsou jazyky               1.0
# Sold To            Lithuanian
# Languages      ['Lithuanian']
# Name: 256, dtype: object
# jsou jazyky                               1.0
# Sold To                                  None
# Languages      ['Complex Chinese', 'Italian']
# Name: 257, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Catalan, English, French, German, Italian, Kor...
# Languages      ['Korean', 'Vietnamese', 'Simplified Chinese',...
# Name: 258, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Dutch', 'Italian', 'Catalan', 'Spanish', 'Th...
# Name: 259, dtype: object
# jsou jazyky                                                  1.0
# Sold To          Catalan, English, Georgian, Portuguese, Spanish
# Languages      ['Georgian', 'Catalan; Spanish', 'English', 'P...
# Name: 260, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 261, dtype: object
# jsou jazyky                                                  1.0
# Sold To             Polish, Hungarian, Bulgarian, Korean, German
# Languages      ['Hungarian', 'Bulgarian', 'Polish', 'Korean',...
# Name: 262, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 263, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 264, dtype: object
# jsou jazyky                                               1.0
# Sold To                           Simplified Chinese, Russian
# Languages      ['Simplified Chinese', 'Ukrainian', 'Russian']
# Name: 265, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Arabic, Armenian, Bulgarian, Catalan, Complex ...
# Languages      ['English', 'Catalan; Spanish', 'Complex Chine...
# Name: 266, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 267, dtype: object
# jsou jazyky            1.0
# Sold To            English
# Languages      ['English']
# Name: 268, dtype: object
# jsou jazyky                                                  1.0
# Sold To          Spanish for Europe, Simplified Chinese, Italian
# Languages      ['Spanish', 'Simplified Chinese', 'Italian', '...
# Name: 269, dtype: object
# jsou jazyky             1.0
# Sold To            Croatian
# Languages      ['Croatian']
# Name: 270, dtype: object
# jsou jazyky                                                  1.0
# Sold To                   Simplified Chinese, Russian, Ukrainian
# Languages      ['Simplified Chinese', 'Dutch', 'Russian', 'Co...
# Name: 271, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 272, dtype: object
# jsou jazyky            1.0
# Sold To               None
# Languages      ['Russian']
# Name: 273, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 274, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Dutch, English, Korean, Russian, Serbian, Span...
# Languages      ['German', 'Ukrainian', 'Simplified Chinese', ...
# Name: 275, dtype: object
# jsou jazyky                                                  1.0
# Sold To                 English, Serbian, Spanish, Thai, Turkish
# Languages      ['Simplified Chinese', 'Slovene', 'Italian', '...
# Name: 276, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, Hungarian, Simplified Chinese, Thai, ...
# Languages      ['Russian', 'Ukrainian', 'Vietnamese', 'Simpli...
# Name: 277, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, Hungarian, Simplified Chinese, Thai, ...
# Languages      ['Russian', 'Ukrainian', 'Estonian', 'Vietname...
# Name: 278, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Complex Chinese, French, Polish, Simplified Ch...
# Languages      ['Simplified Chinese', 'Ukrainian', 'Spanish',...
# Name: 279, dtype: object
# jsou jazyky                                                  1.0
# Sold To             Complex Chinese, English, Korean, Vietnamese
# Languages      ['German', 'Slovene', 'Russian', 'French', 'Si...
# Name: 280, dtype: object
# jsou jazyky                                                  1.0
# Sold To                     Complex Chinese, English, Vietnamese
# Languages      ['German', 'Slovene', 'Russian', 'French', 'Ko...
# Name: 281, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 282, dtype: object
# jsou jazyky                                           1.0
# Sold To                         English, Italian, Spanish
# Languages      ['Italian', 'English', 'Spanish', 'Uzbek']
# Name: 283, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 284, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 285, dtype: object
# jsou jazyky            1.0
# Sold To            Turkish
# Languages      ['Turkish']
# Name: 286, dtype: object
# jsou jazyky                                       1.0
# Sold To                                       Turkish
# Languages      ['English (non-exclusive)', 'Turkish']
# Name: 287, dtype: object
# jsou jazyky            1.0
# Sold To            Turkish
# Languages      ['Turkish']
# Name: 288, dtype: object
# jsou jazyky                                 1.0
# Sold To              German, Simplified Chinese
# Languages      ['German', 'Simplified Chinese']
# Name: 289, dtype: object
# jsou jazyky    None
# Sold To        None
# Languages      None
# Name: 290, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                     None
# Languages      ['Swedish', 'Danish', 'Finnish', 'Serbian', 'R...
# Name: 291, dtype: object
# jsou jazyky                                 1.0
# Sold To             Korean, Simplified  Chinese
# Languages      ['Simplified Chinese', 'Korean']
# Name: 292, dtype: object
# jsou jazyky                                            1.0
# Sold To                  English, Italian, Korean, Spanish
# Languages      ['English', 'Spanish', 'Korean', 'Italian']
# Name: 293, dtype: object
# jsou jazyky                                                  1.0
# Sold To        English, French, Serbian, Slovene, Spanish, Uz...
# Languages      ['English', 'Slovene', 'Spanish', 'French', 'V...
# Name: 294, dtype: object
# jsou jazyky                                                  1.0
# Sold To        Bulgarian, English, Italian, Korean, Russian, ...
# Languages      ['Simplified Chinese', 'Italian', 'Korean', 'S...
# Name: 295, dtype: object
# jsou jazyky                                                  1.0
# Sold To                                                Mongolian
# Languages      ['Spanish', 'Italian', 'Simplified Chinese', '...
# ...
# Sold To        NaN
# Languages      NaN
# Name: 1329, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1330, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1331, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1332, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1333, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1334, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1335, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1336, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1337, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1338, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1339, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1340, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1341, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1342, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1343, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1344, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1345, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1346, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1347, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1348, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1349, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1350, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1351, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1352, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1353, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1354, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1355, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1356, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1357, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1358, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1359, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1360, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1361, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1362, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1363, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1364, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1365, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1366, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1367, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1368, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1369, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1370, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1371, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1372, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1373, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1374, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1375, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1376, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1377, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1378, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1379, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1380, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1381, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1382, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1383, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1384, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1385, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1386, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1387, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1388, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1389, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1390, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1391, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1392, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1393, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1394, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1395, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1396, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1397, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1398, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1399, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1400, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1401, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1402, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1403, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1404, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1405, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1406, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1407, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1408, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1409, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1410, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1411, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1412, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1413, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1414, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1415, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1416, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1417, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1418, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1419, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1420, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1421, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1422, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1423, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1424, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1425, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1426, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1427, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1428, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1429, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1430, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1431, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1432, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1433, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1434, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1435, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1436, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1437, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1438, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1439, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1440, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1441, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1442, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1443, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1444, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1445, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1446, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1447, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1448, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1449, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1450, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1451, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1452, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1453, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1454, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1455, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1456, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1457, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1458, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1459, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1460, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1461, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1462, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1463, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1464, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1465, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1466, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1467, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1468, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1469, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1470, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1471, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1472, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1473, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1474, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1475, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1476, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1477, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1478, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1479, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1480, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1481, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1482, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1483, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1484, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1485, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1486, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1487, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1488, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1489, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1490, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1491, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1492, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1493, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1494, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1495, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1496, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1497, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1498, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1499, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1500, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1501, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1502, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1503, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1504, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1505, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1506, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1507, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1508, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1509, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1510, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1511, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1512, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1513, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1514, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1515, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1516, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1517, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1518, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1519, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1520, dtype: object
# jsou jazyky    NaN
# Sold To        NaN
# Languages      NaN
# Name: 1521, dtype: object

# %%
prehled_vse.to_excel('excel tables/Prehled_vse_extra.xlsx',index=False)
